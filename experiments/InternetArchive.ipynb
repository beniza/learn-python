# %% [markdown]
# # Manipulating the items on the archive.org website
# The `archive.org` is arguably the largest collection of community contributed collection of `items` such as books, movies, audio, images and even code. The snippets in this notebook can be used for automating your interactions with the `archive.org` servers.
#
# In order for making the interactions smoother, they've released a python library named `internetarchive` with serveral methods that will allow you in seemlessly interact with their servers.
#
# Keep in mind that you need to configure your work system before you can start interacting with the servers, especially if you are planning to make changes on the items you've submitted on `archive.org` website.

# %% [markdown]
# ## Configuring your system
# The first step is to configure the system for using library. They have a tiny script, `ia`, that will help you configure and secure your account.

# %% [markdown]
# TODO: Write the steps to use `ia`.

# %%
from internetarchive import upload, get_item, modify_metadata, search_items

# %% [markdown]
# ## Reading the Metadata of an exisiting item
# An item on archive.org represents a single entry on the server's catalogue. Each item has two parts: its actual file(s), as well as its description. The description of an item is known as the metadata. You can access all of an item's metadata via the `item` object.

# %%
# To get the details of an item, you'd need the identifier
item = get_item('vilpattukaltest1980kssp')
item.item_metadata['metadata']
# Out:
# {'identifier': 'vilpattukaltest1980kssp',
#  'mediatype': 'texts',
#  'collection': ['kssp-archives', 'kerala-archives', 'additional_collections'],
#  'creator': 'Kerala Sasthra Sahithya Parishad',
#  'date': '1980',
#  'description': 'വിൽപ്പാട്ടുകൾ',
#  'language': 'mal',
#  'licenseurl': 'https://creativecommons.org/licenses/by-sa/4.0/',
#  'scanner': 'Internet Archive HTML5 Uploader 1.6.4',
#  'title': 'വിൽപ്പാട്ടുകൾ - ശാസ്ത്രകലാജാഥ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്',
#  'uploader': 'shijualexonline@gmail.com',
#  'publicdate': '2020-03-16 16:06:06',
#  'addeddate': '2020-03-16 16:06:06',
#  'identifier-access': 'http://archive.org/details/vilpattukaltest1980kssp',
#  'identifier-ark': 'ark:/13960/t0wq8k30h',
#  'imagecount': '20',
#  'ppi': '600',
#  'ocr': 'language not currently OCRable',
#  'year': '1980',
#  'subject': 'Kilipattu;  1982'}

# %% [markdown]
# ## Upload an item
# It's fairly easy to establish a connection for creating an item on archive.org and uploading file to it. Remember that we need to upload both the actual files and metadata when we create a new item.
#
# > If the item already has a file with the same filename, the existing file within the item will be overwritten.

# %%
# metadata is submitted to the archive.org as a dictionary. Remember that the subject element must be a simi-colon separated string 
md = dict(title='Title of the item', mediatype='movies', subject='test; magazines')

# %%
r = upload('ia-test-upload', files=['test.txt'], metadata=md)

# %%
r[0].status_code
# Out:
# 200

# %% [markdown]
# **Success**
#
# This has created the above item on the archive.org site.
# [Title of the item](https://archive.org/details/ia-test-upload)

# %% [markdown]
# ## Modify the metadata

# %%
item_id = "kalivela2002kssp"
item = get_item(item_id)
cur_sub = item.item_metadata['metadata']['subject']
print(cur_sub)
cur_sub = "; ".join([lambda sub: sub.strip()[for su])
rem
if item_id and new_sub:
    r = modify_metadata(item_id, metadata=dict(subject=new_sub))
    r.status_code

# %%
item_id = "kalivela2002kssp"
item = get_item(item_id)
cur_sub = item.item_metadata['metadata']['subject']

# %%
rem_sub = 'Kerala Archives'
print(cur_sub)
cur_sub.pop(cur_sub.index('Kerala Archives'))
print(cur_sub)
# Out:
# ['KSSP leaflets', 'Kerala Archives']
# ['KSSP leaflets']

# %%
kssp = list(search_items('kssp-archives'))

# %%
for book in kssp:
    print(book['identifier'])
# Out:
# 1966octsasthraga0000kssp
# 1969decsasthrake0000kssp
# 1969novsasthrake0000kssp
# 1969sathrakerala0000kssp
# 1970augeureka0000kssp
# 1970deceureka0000kssp
# 1970febsasthrake0000kssp
# 1970jansasthrake0000kssp
# 1970marsasthrake0000kssp
# 1970maysasthrake0000kssp
# 1970noveureka0000kssp
# 1970sepeureka0000kssp
# 1970sepeureka0000kssp_v4f2
# 1971apreureka0000kssp
# 1971febeureka0000kssp
# 1971janeureka0000kssp
# 1971mareureka0000kssp
# 1971mayeureka0000kssp
# 1983arogyarekha0000kssp
# 1983mannan0000rajm
# 1983nammudearogy0000ekba
# 1983pradhamasusr0000jaya
# 1984marunnuvyvas0000ekba
# 1984urjamchandra0000kssp
# 1985arationalstu0000jami
# 1985raionalityst0000shis
# 1986vaidyuthipra0000kssp
# 1986vaithyuthipr0000kssp
# 1986vanamvellam0000kssp
# 1986vyavasayaval0000kssp
# 1986vyavasayaval0000unse
# 1987janakeeyaaro0000kssp
# 1988vaidyuthikan0000mppa
# 1988vaidyuthinir0000unse
# 1989aksharathiln0000kssp
# 1989arogyasurvey0000kssp
# 1989deseeyavanit0000kssp
# 1989parishathums0000kssp
# 1989parishathums0000kssp_z0l1
# 1989randayiraman0000kssp
# 1989rogaprathiro0000kssp
# 1989sthreekalude0000kssp
# 1989sthreekalums0000kssp
# 1989sthreekalums0000kssp_d4r6
# 1990jalajanyarog0000kssp
# 1990keratintevai0000kssp
# 1990vanithakalum0000kssp
# 1990vanithangalu0000kssp
# 1992healthpolicy0000kssp
# 1992kerathinuoru0000kssp
# 1992marunnukalud0000kssp
# 1993samuhyasamra0000kssp
# 1993sthreekalude0000para
# 1993vanithasasth0000kssp
# 1994elippaniyump0000kssp
# 1994urjarekha0000unse
# 1995arogyarangat0000kssp
# 1995bhashasamska0000kssp
# 1995bodhanamadhy0000kssp
# 1995janakeeyvidy0000kssp
# 1995keralavidyab0000kssp
# 1995parishathuma0000kssp
# 1995swashrayavid0000kssp
# 1995urjavivadamkssp
# adhikaramjanangalkkufirstedn1989kssp
# adhikaramjanangalkkusecondedn1989kssp
# aksharajathaganangal1989kssp
# aksharakalajatha1989kssp
# aksharam1989kssp
# aksharam1989mhrdgoi
# alamarayileswapnangal0000kssp
# ammaparayunnu1992kssp
# asthama0000kssp
# aushadhavilavard0000ekba
# ayesteeyes1989kssp
# badalbudjet1993kssp
# balavedidinam1991kssp
# balikalathilekku1985kssp
# balolasavajatha1986kssp
# balolsavam1987kssp
# bruno1985kssp
# cheruthumvaluthum1984kssp
# chithrangalktrvarma1979kssp
# cvraman1982kssp
# denkelnirdhesam1992kssp
# deshabhimana1993kssp
# dhooredhooredhoore1990prmadhavapanicker
# ekmdistliteracy1990kssp
# eurekakalikal1992kssp
# eurekamagazinevo0000kssp
# eurekamagazinevo0000kssp_b8f9
# expresshway2004kssp
# ezhuthupusthakam1989kssp
# ganithamekmlit1989kssp
# gattumnayangalum1994kssp
# geethangal1980kssp
# gramavikasanarekha1984kssp
# hallydhumakethu1986kssp
# indiayerakshikkan1992kssp
# irupathonnamnutandu1986kssp
# isrocharacase1995kssp
# janakeeyasasthraprasthanam1992kssp
# janakeeyasuthranavivadam2003kssp
# janakiyasuthranam2002kssp
# janangal1989kssp
# jwala0000kssp
# kalarppuvasthukkal0000kssp
# kalikkamaravindgupta1990kssp
# kalikoottam1992kssp
# kalivela2002kssp
# kallukalkrama1979kssp
# kannethathaprmad1983kssp
# kanyabhoomi1990kssp
# kariyunnakalpavriksham1984kssp
# karshikameghala1993kssp
# kavimalika1986kssp
# kayalnammude1991kssp
# keralapanchayathraj1995kssp
# keralathilevidyabhyasam1994kssp
# keralathintesampathu1984edn6kssp
# keralathinuoruar0000kssp
# keralavikasanam0000kssp
# keramulamkadukal0000kssp
# kilikoottam0000kssp
# kssp-archives
# kssp-inaguration1962kssp
# ksspsilentvalley0000kssp
# ksspsouvenir1983kssp
# ksspurjapathisan0000kssp
# kushtaraogam0000kssp
# leadkindlylight1989kssp
# mahothsavam1997kssp
# mamsamthinnunnasasyangal0000kssp
# manushyankatha1989ekmlit
# maramparanja0000kssp
# marichavareadakal1984kssp
# medicalsamaram0000ekba
# mochanam1982kssp
# mollakkayudekuthira1987kssp
# nadakangal1981kssp
# nadakasilpasala0000kssp
# naleyudempp1983kssp
# nallanaale1989ekmlit
# nammalariyan2000kssp
# nammalonnu1986kssp
# namukkuchuttumullalokam1989kssp
# narakam1981kssp
# navamalika1987kssp
# njansthree1990kssp
# onnaampadam1995kssp
# orudheeraswapnam1994kssp
# orukunjujanikkunnu0000kssp
# orumaramoruvaram1987kssp
# othukali1984kssp
# ottanthullalukal1980kssp
# padanolsavam1998kssp
# panayapeduthiyabhavi1992kssp
# papi1981kssp
# parishathaduppu0000kssp
# parishathenthucheyyunnu0000kssp
# parisheelanarekha1981kssp
# parisheelanarekha1982kssp
# paristhathaduppu0000kssp
# pattukal1980kssp
# pavanadakangal1988kssp
# penakalkadha1990kssp
# petamma1995kssp
# pkdjillavikasana1981kssp
# prathirodham0000kssp
# punyabhumiyudethengal1992kssp
# puthanpattukar1987kssp
# puthiyapadypadhathi1999kssp
# saksharathayanjamrandam1991kssp
# samathalam1981kssp
# samathavinjanotsavam1997kssp
# samoohyamanushyanum1982kssp
# sampathikaparishkaram1991kssp
# samrajyatham1992kssp
# santhigeetham1987kssp
# sasthragathifeb1968kssp
# sasthragathijan1967kssp
# sasthragathijuly1967kssp
# sasthrageethika1984kssp
# sasthragitha0000kssp
# sasthrakeralam0000kssp
# sasthrakeralammay1974kssp
# sasthramgramangalkku1982kssp
# sasthramgrameenarkku1983kssp
# sasthraparimathru2001kssp
# sasthrapariulgha1962kssp
# sasthrasankethika1993kssp
# seetha1985kssp
# sevanamekhala1993kssp
# silentvalleychar0000kssp
# silentvalleyjala0000kssp
# silentvalleypari0000kssp
# sisuvidyabhyasam1999kssp
# soapinterast2001kssp
# souraaduppu0000pgpa
# spartacs1981kssp
# stateconventiono0000kssp
# sthreekalumpinth0000sama
# sthreekalumsaksh0000kssp
# suryanteathmakadha1979kssp
# susthiravikasanamjankeeya2018kssp
# swasryakalajatha0000kssp
# thengumvazhayum0000kssp
# thiricharivu1989kssp
# thudarsaksharatha1992kssp
# unarthupaatu1989kssp
# unnathavidyabhyasa1999kssp
# urjamchodyothara0000kssp
# vanagatha0000kssp
# vanaparvam1981kssp
# vanitharekha1987kssp
# vayarilakkam0000kssp
# vayarilakkamchar0000rajm
# velichamenayi1989kssp
# velichamenayicha1989kssp
# velichathilekku1989kssp
# vidyapari2007kssp
# vidyaparvam1995kssp
# vikasanajatha1998kssp
# vikasanamjanangal1989ekmlit
# vikendreekrithaasoothranam0000kssp
# vilapesal1983kssp
# vilpattukal1980kssp
# vilpattukaltest1980kssp
# vipanikal1994kssp
# visittosilentval0000mssw
# vithuvaypa1993kssp
# vyavasayameghala1992kssp
# vyavasayamgramam1981kssp
# vyavasayasouvenir1980kssp
# vyavasayavalkaranam1986kssp
# yudham1981kssp

# %%
for item_id in kssp:
    item = get_item(item_id['identifier'])
    cur_sub = item.item_metadata.get(['metadata']['subject'], "")
    print(cur_sub, type(cur_sub))
#     try:
#         cur_sub.pop(cur_sub.index('Kerala Archives'))
#     except AttributeError:
#         cur_sub = cur_sub.replace('Kerala Archives;', "")
#     print(cur_sub)
#     r = modify_metadata(item, metadata=dict(subject=cur_sub))
#     if r.status_code == 200:
#         print("Successfully updated the subject of {} as {}".format(item, cur_sub))
#     else:
#         print("Something went wrong while updating the subject of {} as {}".format(item, cur_sub))
# Out:
# Sasthragathi <class 'str'>
# Sasthra Keralam Magazine <class 'str'>
# Sasthra Keralam Magazine, KSSP Science Magazine <class 'str'>
# Sasthra Keralam Magazine, Malayalam Science Magazine <class 'str'>
# Eureka Magazine, Malayalam Children's Magazine <class 'str'>
# Eureka Magazine, Malayalam Children's Magazine <class 'str'>
# Sasthra Keralam Magazine, KSSP Science Magazine <class 'str'>
# Sasthra Keralam Magazine, KSSP Science Magazine <class 'str'>
# Sasthra Keralam Magazine, KSSP Science Magazine <class 'str'>
# Sasthra Keralam Magazin; Malayalam Science Magazine <class 'str'>
# Eureka Magazine, Malayalam Children's Magazine <class 'str'>
# Eureka Magazine, Malayalam Children's Magazine <class 'str'>
# Eureka Magazine, Malayalam Children's Magazine <class 'str'>
# Eureka Magazine, Malayalam Children's Magazine <class 'str'>
# Eureka Magazine <class 'str'>
# Eureka Magazine, Malayalam Children's Magazine <class 'str'>
# Eureka Magazine, Malayalam Children's Magazine <class 'str'>
# Eureka Magazine <class 'str'>
# KSSP leaflets;KSSP Health Books <class 'str'>
# KSSP leaflets;KSSP Health Books, Measles <class 'str'>
# KSSP leaflets; Kerala Health <class 'str'>
# KSSP leaflets; First aid, KSSP Health Books <class 'str'>
# KSSP leaflets; KSSP Health Books <class 'str'>
# KSSP leaflets;KSSP Books about Power <class 'str'>
# KSSP leaflets;KSSP Health Books <class 'str'>
# KSSP leaflets;KSSP Health Books <class 'str'>
# KSSP leaflets;Kerala Energy Problem;KSSP Energy Books <class 'str'>
# KSSP leaflets;KSSP Energy Books;Power Problex in Kerala <class 'str'>
# KSSP leaflets;Kerala Energy;KSSP Ecology Books <class 'str'>
# KSSP leaflets; KSSP Development Books; Kerala Development <class 'str'>
# KSSP leaflets; KSSP Development Books; Kerala Development <class 'str'>
# KSSP leaflets;KSSP Health Books;Health Survey <class 'str'>
# KSSP leaflets;Kerala Energy Problem;KSSP Energy Books <class 'str'>
# KSSP leaflets;Kerala Power Problem <class 'str'>
# KSSP leaflets;KSSP Health Books;Kerala Health Problem <class 'str'>
# KSSP leaflets;KSSP Health Books;Health Survey <class 'str'>
# KSSP leaflets;KSSP Gender Books <class 'str'>
# KSSP leaflets about Gender <class 'str'>
# KSSP leaflets;KSSP Gender Books <class 'str'>
# KSSP leaflets;KSSP Health Books <class 'str'>
# KSSP leaflets;KSSP Health Books;Health Survey <class 'str'>
# KSSP leaflets; KSSP Books about Gender Bias <class 'str'>
# KSSP leaflets;KSSP Gender Books <class 'str'>
# KSSP leaflets;KSSP Gender Books <class 'str'>
# KSSP leaflets;KSSP Health Books <class 'str'>
# KSSP leaflets;Kerala Energy Problem;KSSP Energy Books <class 'str'>
# KSSP leaflets;KSSP Gender Books <class 'str'>
# KSSP leaflets;KSSP Gender Books;Civil Code and Gender Bias <class 'str'>
# KSSP leaflets;KSSP Health Books <class 'str'>
# KSSP leaflets;KSSP Health Books <class 'str'>
# KSSP leaflets;KSSP Health Books;Medicine Price Hike <class 'str'>
# KSSP leaflets;KSSP Gender Books;Gender Bias <class 'str'>
# KSSP leaflets; Women's Health; KSSP Books about Health; KSSP books about women <class 'str'>
# KSSP leaflets;KSSP Gender Books;Gender Bias in Kerala <class 'str'>
# KSSP leaflets;KSSP Health Books;Leptospirosis;Plague <class 'str'>
# KSSP leaflets;Power Problem of Kerala, KSSP Books about Power <class 'str'>
# KSSP leaflets;KSSP Health Books <class 'str'>
# KSSP leaflets;Kerala Public Education;KSSP Education Books <class 'str'>
# KSSP leaflets;Kerala Public Education;KSSP Education Books; Vidyabhyasa Jadha-95 <class 'str'>
# KSSP leaflets;Kerala Public Education;KSSP Education Books;Vidyabhyasa Jadha-95 <class 'str'>
# KSSP leaflets;Kerala Public Education, Vidyabhyasa Jadha-95 <class 'str'>
# KSSP leaflets;Kerala Public Education;KSSP Education Books;KSSP and Education Debates <class 'str'>
# KSSP leaflets; Kerala Education; KSSP Books about Education; Vidyabhyasa Jadha-95 <class 'str'>
# ['Kerala Electricity', 'KSSP leaflets', 'Kerala Energy'] <class 'list'>
# ['Planning, evelopment', 'Kerala Archives'] <class 'list'>
# ['Decentralization, Planning, Democracy', 'Kerala Archives'] <class 'list'>
# Kala Jatha, Street Theatre <class 'str'>
# ['Ernakulam District Total Literarcy Programme', 'Kerala Literacy'] <class 'list'>
# Ernakulam District Total Literarcy Programme <class 'str'>
# ['Ernakulam District Total Literarcy Programme', 'Kerala Literacy'] <class 'list'>
# Kilikkkoottam Jadha, Street Theatre <class 'str'>
# Street Theatre <class 'str'>
# Health Education, Asthma <class 'str'>
# KSSP leaflets;KSSP Health Books <class 'str'>
# Kala Jatha, Street Theatre <class 'str'>
# ['Economics, Badjet', 'Kerala Swashraya Samithy'] <class 'list'>
# Balavedi, Science History <class 'str'>
# Sasthra Kala Jatha, Street Theatre <class 'str'>
# Balalsava Jatha, Street Theatre <class 'str'>
# Balolsava Songs <class 'str'>
# Sasthra Kala Jatha, Street Theatre <class 'str'>
# kssp-science books, P R Madhavappanikkar, Malayalam Physics Books <class 'str'>
# Painting, Art, History <class 'str'>
# Science Education, Biography, C V Raman <class 'str'>
# ['Dunkal Draft', 'Kerala Archives'] <class 'list'>
# ['New Economic Policy of India, Kerala Swasraya Samithi', 'Kerala Sasthra Sahithya Parishad'] <class 'list'>
# ['kssp-science books', 'P R Madhavappanikkar', 'Malayalam Physics Books'] <class 'list'>
# ['Ernakulam District Total Literarcy Programme', 'Kerala Literacy'] <class 'list'>
# Science Education <class 'str'>
# Eureka Magazine, Malayalam Children's Magazine <class 'str'>
# Eureka Magazine <class 'str'>
# Kerala Development, Express Highway, Jalanidhi <class 'str'>
# ['Ernakulam District Total Literarcy Programme', 'Kerala Literacy'] <class 'list'>
# ['Ernakulam District Total Literarcy Programme; Mathematics Hand Book', 'Kerala Literacy'] <class 'list'>
# ['Globalization, Gatt Agreement', 'Kerala Swashraya Samithy'] <class 'list'>
# ['Sasthra Kala Jatha', 'Kerala Archives'] <class 'list'>
# Kerala Economy, Rural Development <class 'str'>
# Astronomy, Halley's comet <class 'str'>
# ['Globalization, Dunkal Draft, Indian Economy', 'Kerala Swashraya Samithy'] <class 'list'>
# Sasthra Kala Jatha, Street Theatre <class 'str'>
# ['ISRO; KSSP leaflets', 'Kerala Archives'] <class 'list'>
# People's Science Movement in Kerala <class 'str'>
# People's Planning <class 'str'>
# People's Planning; Participative Democracy, Decentralization <class 'str'>
# ['Education, Literacy', 'Kerala Literacy'] <class 'list'>
# Bhopal Gas Tragedy <class 'str'>
# Science Education, Adulteration <class 'str'>
# Malayalam Science Education Books <class 'str'>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-93-076181f1fbdb> in <module>
#       1 for item_id in kssp:
#       2     item = get_item(item_id['identifier'])
# ----> 3     cur_sub = item.item_metadata['metadata']['subject']
#       4     print(cur_sub, type(cur_sub))
#       5 #     try:
#
# KeyError: 'subject'

# %%
for item_id in kssp[107:]:
    item = get_item(item_id['identifier'])
#     print(item)
    try:
        cur_sub = item.item_metadata['metadata']['subject']
    except Exception as e:
        cur_sub = str(e)
        pass
    item_title = item.item_metadata
    print(cur_sub, type(cur_sub))
# Out:
# Malayalam Science Education Books <class 'str'>
# Malayalam Science Education Books <class 'str'>
# ['KSSP leaflets', 'Kerala Archives'] <class 'list'>
# ['Parishath Geology Books, Rock', 'KSSP Books'] <class 'list'>
# Astronomy, Cosmology <class 'str'>
# ['Bharat Gyanvigyan Samithi Kerala, Street Theatre in Kerala, Literacy, Gender', 'Kerala Sasthra Sahithya Parishad', 'Kerala Archives'] <class 'list'>
# Kerala Coconut Industry; KSSP leaflets <class 'str'>
# ['Dunkal Draft, New Economic Policy, Agriculture', 'Kerala Swashraya Samithy'] <class 'list'>
# Kala Jatha, Street Theatre <class 'str'>
# Kala Jatha, Ecology <class 'str'>
# Kerala Panchayathraj <class 'str'>
# Education <class 'str'>
# KSSP General Documents <class 'str'>
# KSSP leaflets;KSSP Health Books;Kerala Health Books <class 'str'>
# ['Development, Decentralization', 'Kerala Archives'] <class 'list'>
# ['Bamboo', 'Kerala Environment'] <class 'list'>
# Kala Jatha, Street Theatre <class 'str'>
# Kala Jatha, Street Theatre <class 'str'>
# news kssp-inaguration <class 'str'>
# KSSP leaflets; Silent Valley <class 'str'>
# KSSP Souvenir <class 'str'>
# KSSP leaflets, Power Problem in Kerala, Kayamkulam Thermal Station KSSP Books about Energy <class 'str'>
# Health, leprosy <class 'str'>
# ['Ernakulam District Total Literarcy Programme', 'Kerala Literacy'] <class 'list'>
# Kala Jatha, Street Theatre <class 'str'>
# carnivorous plants <class 'str'>
# ['History', 'Ernakulam District Total Literarcy Programme'] <class 'list'>
# Environment <class 'str'>
# Kala Jatha, Street Theatre <class 'str'>
# KSSP leaflets;KSSP Health Books <class 'str'>
# Sasthra Kala Jatha, Street Theatre <class 'str'>
# Sasthra Kala Jatha, Street Theatre <class 'str'>
# ['Sasthra Kala Jatha, Street Theatre', 'Kerala Archives'] <class 'list'>
# Street Theatre <class 'str'>
# ['politics', 'KSSP Books'] <class 'list'>
# ['KSSP- Health Education Books; Ernakulam District Total Literarcy Programme', 'Ernakulam District Total Literarcy Programme'] <class 'list'>
# Globalization <class 'str'>
# Kala Jatha, Street Theatre <class 'str'>
# Ernakulam District Total Literarcy Programme; Malayalam Science Books <class 'str'>
# ['Sasthra Kala Jatha, Street Theatre', 'Kerala Archives'] <class 'list'>
# Sasthra Kala Jatha, Street Theatre <class 'str'>
# Kala Jatha, Street Theatre <class 'str'>
# Kala Jatha, Street Theatre, Kerala Education <class 'str'>
# Sasthra Kala Jatha, Street Theatre <class 'str'>
# Reproduction, Sex Education <class 'str'>
# Balalsava Jatha, Street Theatre <class 'str'>
# Kala Jatha, Street Theatre <class 'str'>
# ['Sasthra Kala Jatha, Street Theatre', 'Kerala Archives'] <class 'list'>
# Development <class 'str'>
# ['Kerala Swasraya Samithi, Economic Policy', 'Kerala Swashraya Samithy'] <class 'list'>
# ['Sasthra Kala Jatha, Street Theatre', 'Kerala Archives'] <class 'list'>
# KSSP leaflets;Parishathaduppu <class 'str'>
# ["People's science movement", 'Kerala Archives'] <class 'list'>
# ["People's science movement", 'Kerala Archives'] <class 'list'>
# ["KSSP Cadre Education, People's Science Movement", 'Kerala Archives'] <class 'list'>
# KSSP leaflets;Parishathaduppu <class 'str'>
# KSSP Songs <class 'str'>
# Sasthra Kala Jatha, Street Theatre, Puppetry Script <class 'str'>
# ['Bharat Gyanvigyan Samithi Kerala, Street Theatre in Kerala, Literacy, Gender', 'Kerala Sasthra Sahithya Parishad', 'Kerala Archives'] <class 'list'>
# Kala Jatha, Street Theatre <class 'str'>
# ['Development Palakkad', 'Kerala Development'] <class 'list'>
# vaccination <class 'str'>
# Kala Jatha, Street Theatre <class 'str'>
# Sasthra Kala Jatha, Street Theatre <class 'str'>
# Education <class 'str'>
# Education, Literacy <class 'str'>
# ['Sasthra Kala Jatha, Street Theatre', 'Kerala Archives'] <class 'list'>
# ['Bharat Gyanvigyan Samithi Kerala, Samatha Vijnanolsavam, Gender', 'Kerala Sasthra Sahithya Parishad', 'Kerala Archives'] <class 'list'>
# Science Education <class 'str'>
# ['Globalization, New Economic Policy', 'Kerala Archives'] <class 'list'>
# ['Imperialism, Globalization', 'Kerala Swashraya Samithy'] <class 'list'>
# Kala Jatha, Street Theatre <class 'str'>
# Sasthragathi <class 'str'>
# Sasthragathi <class 'str'>
# ['Malayalam Science Magazine', 'Sasthragathi'] <class 'list'>
# Kala Jatha, Street Theatre <class 'str'>
# Grama Sasthra Jatha <class 'str'>
# Sasthra Keralam Magazine, Malayalam Science Magazine <class 'str'>
# Sasthra Keralam Magazine <class 'str'>
# Grama Sasthra Jatha <class 'str'>
# Grama Sasthra Jatha <class 'str'>
# K.G. Adiyodi <class 'str'>
# ['KSSP Souvenir', 'KSSP General Documents'] <class 'list'>
# ['Science and Technology Policy', 'Kerala Swashraya Samithy'] <class 'list'>
# Sasthra Kala Jatha, Street Theatre <class 'str'>
# ['Kerala Swasraya Samithi, Globalization, Indian Economy', 'Kerala Swashraya Samithy'] <class 'list'>
# KSSP leaflets; Silent Valley; KSSP Ecology Books <class 'str'>
# KSSP leaflets;Silent Valley <class 'str'>
# KSSP leaflets;Silent Valley <class 'str'>
# Education <class 'str'>
# Science Education, Soap, Indian Soap Industry <class 'str'>
# KSSP leaflets, KSSP energy Books <class 'str'>
# ['Sasthra Kala Jatha,', 'Kerala Archives'] <class 'list'>
# KSSP leaflets;KSSP Health Books;Modern Medical Doctors <class 'str'>
# KSSP leaflets; Samatha leaflets, Gender Bias in Kerala <class 'str'>
# KSSP leaflets;KSSP Gender Books;Gender Bias in Kerala <class 'str'>
# Sun, Energy <class 'str'>
# Development, Flood 2018, Climate Change <class 'str'>
# Kala Jatha, Street Theatre <class 'str'>
# Agriculture, Banana, Coconut <class 'str'>
# Kala Jatha, Street Theatre <class 'str'>
# ['Kerala Literacy, Education', 'Kerala Literarcy'] <class 'list'>
# Kalajatha, Street Drama <class 'str'>
# ['Higher Education Kerala', 'Kerala Education'] <class 'list'>
# KSSP leaflets;Kerala Energy <class 'str'>
# Kala Jatha, Street Theatre, Kerala Environment <class 'str'>
# ['Sasthra Kala Jadha, Street Theatre', 'Kerala Archives'] <class 'list'>
# Gender <class 'str'>
# Health Education, Dysentery <class 'str'>
# KSSP leaflets;KSSP Health Books <class 'str'>
# ['Ernakulam District Total Literarcy Programme', 'Kerala Literacy'] <class 'list'>
# ['Ernakulam District Total Literarcy Programme', 'Kerala Literacy'] <class 'list'>
# ['Ernakulam District Total Literarcy Programme', 'Kerala Literacy'] <class 'list'>
# ['Education', 'Kerala Education'] <class 'list'>
# Kala Jatha, Street Theatre <class 'str'>
# People's Planning; decentralization <class 'str'>
# ['Government welfare schemes in Kerala', 'Ernakulam District Total Literarcy Programme'] <class 'list'>
# ['Decentralization, Planning', 'Kerala Archives'] <class 'list'>
# Sasthra Kala Jatha, Street Theatre <class 'str'>
# Sasthra Kala Jatha, Street Theatre <class 'str'>
# Kilipattu;  1982 <class 'str'>
# Sasthra Kala Jatha, Street Theatre <class 'str'>
# KSSP leaflets;Silent Valley <class 'str'>
# ['Kerala Swasraya Samithi, Indian Agriculture, Globalization', 'Kerala Swashraya Samithy'] <class 'list'>
# ['Globalization, Indian Industry', 'Kerala Swashraya Samithy'] <class 'list'>
# Village Industry, Rural Development <class 'str'>
# KSSP Souvenir <class 'str'>
# Industrialisation of Kerala <class 'str'>
# ['Sasthra Kala Jatha, Street Theatre', 'Kerala Archives'] <class 'list'>

# %%
for item_id in kssp:
    item = get_item(item_id['identifier'])
    cur_sub = False
#     print(item)
    try:
        cur_sub = item.item_metadata['metadata']['subject']
    except Exception as e:
        print(str(e))
        
        pass
    item_title = item.item_metadata['metadata']['title']
    print("{}\t{}\t{}\t{}".format(item_id['identifier'], item_title, cur_sub, normalize_subject(cur_sub), type(cur_sub)))
# Out:
# 1966octsasthraga0000kssp	ശാസ്ത്രഗതി ലക്കം 1 - 1966 ഒക്ടോബർ - കേരള ശാസ്ത്രസാഹിത്യപരിഷത്ത്	Sasthragathi	Sasthragathi
# 1969decsasthrake0000kssp	ശാസ്ത്രകേരളം - സയൻസു മാസിക - 1969 ഡിസംബർ	Sasthra Keralam Magazine	Sasthra Keralam Magazine
# 1969novsasthrake0000kssp	ശാസ്ത്രകേരളം - സയൻസു മാസിക - 1969 നവം‌ബർ	Sasthra Keralam Magazine, KSSP Science Magazine	Sasthra Keralam Magazine; KSSP Science Magazine
# 1969sathrakerala0000kssp	ശാസ്ത്രകേരളം - സയൻസു മാസിക - 1969 ആഗസ്റ്റ്	Sasthra Keralam Magazine, Malayalam Science Magazine	Sasthra Keralam Magazine; Malayalam Science Magazine
# 1970augeureka0000kssp	യുറീക്ക - കുട്ടികളുടെ ശാസ്ത്രമാസിക - 1970 ആഗസ്റ്റ് - വാല്യം 1 ലക്കം 3	Eureka Magazine, Malayalam Children's Magazine	Eureka Magazine; Malayalam Children's Magazine
# 1970deceureka0000kssp	യുറീക്ക - കുട്ടികളുടെ ശാസ്ത്രമാസിക - 1970 ഡിസമ്പർ - വാല്യം 1 ലക്കം 7	Eureka Magazine, Malayalam Children's Magazine	Eureka Magazine; Malayalam Children's Magazine
# 1970febsasthrake0000kssp	ശാസ്ത്രകേരളം - സയൻസു മാസിക - 1970 ഫെബ്രുവരി	Sasthra Keralam Magazine, KSSP Science Magazine	Sasthra Keralam Magazine; KSSP Science Magazine
# 1970jansasthrake0000kssp	ശാസ്ത്രകേരളം - സയൻസു മാസിക - 1970 ജനുവരി	Sasthra Keralam Magazine, KSSP Science Magazine	Sasthra Keralam Magazine; KSSP Science Magazine
# 1970marsasthrake0000kssp	ശാസ്ത്രകേരളം - സയൻസു മാസിക - 1970 മാർച്ച്	Sasthra Keralam Magazine, KSSP Science Magazine	Sasthra Keralam Magazine; KSSP Science Magazine
# 1970maysasthrake0000kssp	ശാസ്ത്രകേരളം - സയൻസു മാസിക - 1970 മേയ്	Sasthra Keralam Magazin; Malayalam Science Magazine	Sasthra Keralam Magazin; Malayalam Science Magazine
# 1970noveureka0000kssp	യുറീക്ക - കുട്ടികളുടെ ശാസ്ത്രമാസിക - 1970 നവമ്പർ - വാല്യം 1 ലക്കം 6	Eureka Magazine, Malayalam Children's Magazine	Eureka Magazine; Malayalam Children's Magazine
# 1970sepeureka0000kssp	യുറീക്ക - കുട്ടികളുടെ ശാസ്ത്രമാസിക - 1970 സെപ്റ്റംബർ - വാല്യം 1 ലക്കം 4	Eureka Magazine, Malayalam Children's Magazine	Eureka Magazine; Malayalam Children's Magazine
# 1970sepeureka0000kssp_v4f2	യുറീക്ക - കുട്ടികളുടെ ശാസ്ത്രമാസിക - 1970 ഒക്ടോബർ - വാല്യം 1 ലക്കം 5	Eureka Magazine, Malayalam Children's Magazine	Eureka Magazine; Malayalam Children's Magazine
# 1971apreureka0000kssp	യുറീക്ക - കുട്ടികളുടെ ശാസ്ത്രമാസിക - 1971 ഏപ്രിൽ	Eureka Magazine, Malayalam Children's Magazine	Eureka Magazine; Malayalam Children's Magazine
# 1971febeureka0000kssp	യുറീക്ക - കുട്ടികളുടെ ശാസ്ത്രമാസിക - 1971 ഫെബ്രുവരി	Eureka Magazine	Eureka Magazine
# 1971janeureka0000kssp	യുറീക്ക - കുട്ടികളുടെ ശാസ്ത്രമാസിക - 1971 ജനുവരി	Eureka Magazine, Malayalam Children's Magazine	Eureka Magazine; Malayalam Children's Magazine
# 1971mareureka0000kssp	യുറീക്ക - കുട്ടികളുടെ ശാസ്ത്രമാസിക - 1971 മാർച്ച്	Eureka Magazine, Malayalam Children's Magazine	Eureka Magazine; Malayalam Children's Magazine
# 1971mayeureka0000kssp	യുറീക്ക - കുട്ടികളുടെ ശാസ്ത്രമാസിക - 1971 മേയ്	Eureka Magazine	Eureka Magazine
# 1983arogyarekha0000kssp	1983 - ആരോഗ്യരേഖ	KSSP leaflets;KSSP Health Books	KSSP leaflets; KSSP Health Books
# 1983mannan0000rajm	1983 - മണ്ണൻ - ഡോ: കെ. രാജ്മോഹൻ	KSSP leaflets;KSSP Health Books, Measles	KSSP leaflets; KSSP Health Books; Measles
# 1983nammudearogy0000ekba	1983 - നമ്മുടെ ആരോഗ്യം - ഡോ: ബി. ഇക്ബാൽ	KSSP leaflets; Kerala Health	KSSP leaflets; Kerala Health
# 1983pradhamasusr0000jaya	1983 - പ്രഥമശുശ്രൂഷ - ഡോ: എൽ. ജയലക്ഷ്മി	KSSP leaflets; First aid, KSSP Health Books	KSSP leaflets; First aid; KSSP Health Books
# 1984marunnuvyvas0000ekba	1984 - മരുന്നു വ്യവസായരംഗത്തെ അശാസ്ത്രീയതകൾ - ഡോ. ബി. ഇക്ബാൽ	KSSP leaflets; KSSP Health Books	KSSP leaflets; KSSP Health Books
# 1984urjamchandra0000kssp	1984 - ഊർജം - സി.വി. ചന്ദ്രൻ	KSSP leaflets;KSSP Books about Power	KSSP leaflets; KSSP Books about Power
# 1985arationalstu0000jami	1985 - A Rational Study of Analgesics and Antipyretics	KSSP leaflets;KSSP Health Books	KSSP leaflets; KSSP Health Books
# 1985raionalityst0000shis	Rationality Study of Anti Diarrhoeal Formulations	KSSP leaflets;KSSP Health Books	KSSP leaflets; KSSP Health Books
# 1986vaidyuthipra0000kssp	1986 - വൈദ്യുതി പ്രതിസന്ധിയും പരിഹാരങ്ങളും	KSSP leaflets;Kerala Energy Problem;KSSP Energy Books	KSSP leaflets; Kerala Energy Problem; KSSP Energy Books
# 1986vaithyuthipr0000kssp	1986 - വൈദ്യുതി - പ്രതിസന്ധിയും പരിഹാരങ്ങളും - കേരള ശാസ്ത്ര സാഹിത്യ പരിഷത്തിന്റെ നിർദ്ദേശങ്ങൾ	KSSP leaflets;KSSP Energy Books;Power Problex in Kerala	KSSP leaflets; KSSP Energy Books; Power Problex in Kerala
# 1986vanamvellam0000kssp	1986 - വനം വെള്ളം വൈദ്യുതി	KSSP leaflets;Kerala Energy;KSSP Ecology Books	KSSP leaflets; Kerala Energy; KSSP Ecology Books
# 1986vyavasayaval0000kssp	1986 - വ്യവസായവല്ക്കരണം (ചോദ്യോത്തരങ്ങൾ) - വന-ഊർജ്ജ-വികസന ജാഥ - 1986 സെപ്റ്റംബർ 1 - 7	KSSP leaflets; KSSP Development Books; Kerala Development	KSSP leaflets; KSSP Development Books; Kerala Development
# 1986vyavasayaval0000unse	1986 - വ്യവസായവല്ക്കരണം (ചോദ്യോത്തരങ്ങൾ) - വന-ഊർജ്ജ-വികസന ജാഥ - 1986 സെപ്റ്റംബർ 1 - 14	KSSP leaflets; KSSP Development Books; Kerala Development	KSSP leaflets; KSSP Development Books; Kerala Development
# 1987janakeeyaaro0000kssp	ജനകീയ ആരോഗ്യസർവെ - 1987 - സർവെ പ്രവർത്തകർക്കുള്ള കൈപുസ്തകം	KSSP leaflets;KSSP Health Books;Health Survey	KSSP leaflets; KSSP Health Books; Health Survey
# 1988vaidyuthikan0000mppa	1988 - കേരളത്തിലെ വൈദ്യുതിപ്രശ്നം കണക്കുകളിലൂടെ - എം.പി. പരമേശ്വരൻ	KSSP leaflets;Kerala Energy Problem;KSSP Energy Books	KSSP leaflets; Kerala Energy Problem; KSSP Energy Books
# 1988vaidyuthinir0000unse	1988 - കേരളത്തിലെ വൈദ്യുതി പ്രതിസന്ധിയും പരിഹാരമാർഗങ്ങളും - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്തിന്റെ നിർദ്ദേശങ്ങൾ	KSSP leaflets;Kerala Power Problem	KSSP leaflets; Kerala Power Problem
# 1989aksharathiln0000kssp	1989 - അക്ഷരത്തിൽ നിന്നു് ആരോഗ്യത്തിലേക്കു്	KSSP leaflets;KSSP Health Books;Kerala Health Problem	KSSP leaflets; KSSP Health Books; Kerala Health Problem
# 1989arogyasurvey0000kssp	1989 - ആരോഗ്യ സർവെ - പ്രാഥമിക പാഠങ്ങൾ	KSSP leaflets;KSSP Health Books;Health Survey	KSSP leaflets; KSSP Health Books; Health Survey
# 1989deseeyavanit0000kssp	1989 - ദേശീയ വനിതാവികസന പരിപ്രേക്ഷ്യം: ഒരു വിമർശനം	KSSP leaflets;KSSP Gender Books	KSSP leaflets; KSSP Gender Books
# 1989parishathums0000kssp	1989 - പരിഷത്തും സ്ത്രീപ്രശ്നവും	KSSP leaflets about Gender	KSSP leaflets about Gender
# 1989parishathums0000kssp_z0l1	1989 - പരിഷത്തും സ്ത്രീപ്രശ്നവും	KSSP leaflets;KSSP Gender Books	KSSP leaflets; KSSP Gender Books
# 1989randayiraman0000kssp	2000ാമാണ്ടോടെ എല്ലാവർക്കും ആരോഗ്യം - സങ്കൽപ്പവും യാഥാർത്ഥ്യവും	KSSP leaflets;KSSP Health Books	KSSP leaflets; KSSP Health Books
# 1989rogaprathiro0000kssp	1989 - രോഗ പ്രതിരോധ സർവെ റിപ്പോർട്ട് - വയനാട് ജില്ല	KSSP leaflets;KSSP Health Books;Health Survey	KSSP leaflets; KSSP Health Books; Health Survey
# 1989sthreekalude0000kssp	1989 - സ്ത്രീകളുടെ പ്രശ്നങ്ങൾ	KSSP leaflets; KSSP Books about Gender Bias	KSSP leaflets; KSSP Books about Gender Bias
# 1989sthreekalums0000kssp	1993 - സ്ത്രീകളും സാമൂഹ്യമാറ്റവും	KSSP leaflets;KSSP Gender Books	KSSP leaflets; KSSP Gender Books
# 1989sthreekalums0000kssp_d4r6	1989 - സ്ത്രീകളും സാമൂഹ്യമാറ്റവും	KSSP leaflets;KSSP Gender Books	KSSP leaflets; KSSP Gender Books
# 1990jalajanyarog0000kssp	1990 - ജലജന്യ രോഗങ്ങൾ	KSSP leaflets;KSSP Health Books	KSSP leaflets; KSSP Health Books
# 1990keratintevai0000kssp	1990 - കേരളത്തിന്റെ വൈദ്യുതി പ്രതിസന്ധി - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്തിന്റെ നിലപാട്	KSSP leaflets;Kerala Energy Problem;KSSP Energy Books	KSSP leaflets; Kerala Energy Problem; KSSP Energy Books
# 1990vanithakalum0000kssp	1990 - വനിതകളും സാക്ഷരതയും	KSSP leaflets;KSSP Gender Books	KSSP leaflets; KSSP Gender Books
# 1990vanithangalu0000kssp	1990 - വനിതകളും വ്യക്തിനിയമങ്ങളും	KSSP leaflets;KSSP Gender Books;Civil Code and Gender Bias	KSSP leaflets; KSSP Gender Books; Civil Code and Gender Bias
# 1992healthpolicy0000kssp	1992 - Health Policy for Kerala - Draft	KSSP leaflets;KSSP Health Books	KSSP leaflets; KSSP Health Books
# 1992kerathinuoru0000kssp	1992 - കേരളത്തിന് ഒരു ആരോഗ്യനയം - കരടുരേഖ	KSSP leaflets;KSSP Health Books	KSSP leaflets; KSSP Health Books
# 1992marunnukalud0000kssp	1992 - മരുന്നുകളുടെ വിലവർധനവും പുതിയ സാമ്പത്തിക നയങ്ങളും	KSSP leaflets;KSSP Health Books;Medicine Price Hike	KSSP leaflets; KSSP Health Books; Medicine Price Hike
# 1993samuhyasamra0000kssp	1993 - സാമൂഹ്യസംരക്ഷണ നിയമങ്ങളും സ്ത്രീകളും	KSSP leaflets;KSSP Gender Books;Gender Bias	KSSP leaflets; KSSP Gender Books; Gender Bias
# 1993sthreekalude0000para	1993 - സ്ത്രീകളുടെ ആരോഗ്യപ്രശ്നങ്ങൾ - ഡോ: സി.എൻ. പരമേശ്വരൻ	KSSP leaflets; Women's Health; KSSP Books about Health; KSSP books about women	KSSP leaflets; Women's Health; KSSP Books about Health; KSSP books about women
# 1993vanithasasth0000kssp	1993 - വനിതാ ശാസ്ത്രസംഗമം - കൈപുസ്തകം	KSSP leaflets;KSSP Gender Books;Gender Bias in Kerala	KSSP leaflets; KSSP Gender Books; Gender Bias in Kerala
# 1994elippaniyump0000kssp	1994 - എലിപ്പനിയും പ്ലേഗും	KSSP leaflets;KSSP Health Books;Leptospirosis;Plague	KSSP leaflets; KSSP Health Books; Leptospirosis; Plague
# 1994urjarekha0000unse	1994 - ഊർജ്ജരേഖ	KSSP leaflets;Power Problem of Kerala, KSSP Books about Power	KSSP leaflets; Power Problem of Kerala; KSSP Books about Power
# 1995arogyarangat0000kssp	1995 - ആരോഗ്യരംഗത്തെ പ്രശ്നങ്ങൾ	KSSP leaflets;KSSP Health Books	KSSP leaflets; KSSP Health Books
# 1995bhashasamska0000kssp	1995 - ജനകീയ വിദ്യാഭ്യാസ നിഷേധം കേരളത്തിൽ	KSSP leaflets;Kerala Public Education;KSSP Education Books	KSSP leaflets; Kerala Public Education; KSSP Education Books
# 1995bodhanamadhy0000kssp	1995 - ബോധന മാധ്യമം മാതൃഭാഷയിൽ	KSSP leaflets;Kerala Public Education;KSSP Education Books; Vidyabhyasa Jadha-95	KSSP leaflets; Kerala Public Education; KSSP Education Books; Vidyabhyasa Jadha-95
# 1995janakeeyvidy0000kssp	1995 - ജനകീയ വിദ്യാഭ്യാസ നിഷേധം കേരളത്തിൽ	KSSP leaflets;Kerala Public Education;KSSP Education Books;Vidyabhyasa Jadha-95	KSSP leaflets; Kerala Public Education; KSSP Education Books; Vidyabhyasa Jadha-95
# 1995keralavidyab0000kssp	1995 - കേരള വിദ്യാഭ്യാസരംഗം വഴിത്തിരിവിൽ	KSSP leaflets;Kerala Public Education, Vidyabhyasa Jadha-95	KSSP leaflets; Kerala Public Education; Vidyabhyasa Jadha-95
# 1995parishathuma0000kssp	1995 - പരിഷത്തും അക്കാദമിക രംഗത്തെ സമരവും	KSSP leaflets;Kerala Public Education;KSSP Education Books;KSSP and Education Debates	KSSP leaflets; Kerala Public Education; KSSP Education Books; KSSP and Education Debates
# 1995swashrayavid0000kssp	1995 - സ്വാശ്രയവിദ്യാഭ്യാസവും സാമൂഹിക നീതിയും	KSSP leaflets; Kerala Education; KSSP Books about Education; Vidyabhyasa Jadha-95	KSSP leaflets; Kerala Education; KSSP Books about Education; Vidyabhyasa Jadha-95
# 1995urjavivadamkssp	1995 - ഊർജവിവാദം പതിറ്റാണ്ടുകളിലൂടെ - ഒരു ചുമർപുസ്തകം	['Kerala Electricity', 'KSSP leaflets', 'Kerala Energy']	Kerala Electricity; KSSP leaflets; Kerala Energy
# adhikaramjanangalkkufirstedn1989kssp	അധികാരം ജനങ്ങൾക്ക് - ഒന്നാം പതിപ്പ് - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	['Planning, evelopment', 'Kerala Archives']	Planning; evelopment; Kerala Archives
# adhikaramjanangalkkusecondedn1989kssp	അധികാരം ജനങ്ങൾക്ക് - രണ്ടാം പതിപ്പ് - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	['Decentralization, Planning, Democracy', 'Kerala Archives']	Decentralization; Planning; Democracy; Kerala Archives
# aksharajathaganangal1989kssp	അക്ഷരജാഥ - ഗാനങ്ങൾ സംഗീത ശില്പങ്ങൾ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Kala Jatha, Street Theatre	Kala Jatha; Street Theatre
# aksharakalajatha1989kssp	അക്ഷര കലാജാഥ 89 - എറണാകുളം ജില്ല സമ്പൂർണ്ണ സാക്ഷരതായജ്ഞം	['Ernakulam District Total Literarcy Programme', 'Kerala Literacy']	Ernakulam District Total Literarcy Programme; Kerala Literacy
# aksharam1989kssp	അക്ഷരം - അധ്യാപനസഹായി - എറണാകുളം ജില്ല സമ്പൂർണ്ണ സാക്ഷരതായജ്ഞം	Ernakulam District Total Literarcy Programme	Ernakulam District Total Literarcy Programme
# aksharam1989mhrdgoi	അക്ഷരം - സാക്ഷരതാ പാഠാവലി - എറണാകുളം ജില്ല സമ്പൂർണ്ണ സാക്ഷരതായജ്ഞം	['Ernakulam District Total Literarcy Programme', 'Kerala Literacy']	Ernakulam District Total Literarcy Programme; Kerala Literacy
# alamarayileswapnangal0000kssp	അലമാരയിലെ സ്വപ്നങ്ങൾ - നാടകങ്ങൾ - കിളിക്കൂട്ടം ജാഥാ സ്ക്രിപ്റ്റ് - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Kilikkkoottam Jadha, Street Theatre	Kilikkkoottam Jadha; Street Theatre
# ammaparayunnu1992kssp	അമ്മ പറയുന്നു - നവോത്ഥാന ജാഥാസ്ക്രിപ്റ്റുകൾ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Street Theatre	Street Theatre
# asthama0000kssp	ആസ്‌ത്‌മ - ഗ്രാമശാസ്ത്രജാഥ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Health Education, Asthma	Health Education; Asthma
# aushadhavilavard0000ekba	ഔഷധ വിലവർധന എന്തുകൊണ്ട്? - ഡോ: ബി. ഇക്ബാൽ	KSSP leaflets;KSSP Health Books	KSSP leaflets; KSSP Health Books
# ayesteeyes1989kssp	ഏയെസ് ടീയെസ് - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Kala Jatha, Street Theatre	Kala Jatha; Street Theatre
# badalbudjet1993kssp	ബജറ്റും ബദൽ ബജറ്റും  – കേരള സ്വാശ്രയ സമിതി	['Economics, Badjet', 'Kerala Swashraya Samithy']	Economics; Badjet; Kerala Swashraya Samithy
# balavedidinam1991kssp	ബാലവേദി ദിനം 1991 - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Balavedi, Science History	Balavedi; Science History
# balikalathilekku1985kssp	ബലിക്കളത്തിലേക്ക് - ഗാനങ്ങൾ നാടകങ്ങൾ സംഗീതശില്പങ്ങൾ - ശാസ്ത്രകലാജാഥ 1985 - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Sasthra Kala Jatha, Street Theatre	Sasthra Kala Jatha; Street Theatre
# balolasavajatha1986kssp	ചങ്ങലക്കണ്ണി - ബാലോത്സവജാഥ സ്ക്രിപ്റ്റുകൾ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Balalsava Jatha, Street Theatre	Balalsava Jatha; Street Theatre
# balolsavam1987kssp	ബാലോത്സവപ്പാട്ടുകൾ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Balolsava Songs	Balolsava Songs
# bruno1985kssp	ബ്രൂണോ - നാടകങ്ങൾ - ശാസ്ത്രകലാജാഥ 1985 - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Sasthra Kala Jatha, Street Theatre	Sasthra Kala Jatha; Street Theatre
# cheruthumvaluthum1984kssp	ചെറുതിൽ ചെറുതും വലുതിൽ വലുതും - പി.ആർ. മാധവപ്പണിക്കർ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	kssp-science books, P R Madhavappanikkar, Malayalam Physics Books	kssp-science books; P R Madhavappanikkar; Malayalam Physics Books
# chithrangalktrvarma1979kssp	1979 - ചിത്രങ്ങളുടെ കഥ - കെ.ടി. രാമവർമ്മ	Painting, Art, History	Painting; Art; History
# cvraman1982kssp	സി.വി. രാമൻ - ശാസ്ത്രപാഠാവലി - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Science Education, Biography, C V Raman	Science Education; Biography; C V Raman
# denkelnirdhesam1992kssp	ഡങ്കെൽ നിർദ്ദേശങ്ങൾ - കോളനിവൽക്കരണത്തിന്റെ പുതിയ മാർഗം - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	['Dunkal Draft', 'Kerala Archives']	Dunkal Draft; Kerala Archives
# deshabhimana1993kssp	ദേശാഭിമാനപരമായ ബദൽ പരിപാടി – കേരള സ്വാശ്രയ സമിതി	['New Economic Policy of India, Kerala Swasraya Samithi', 'Kerala Sasthra Sahithya Parishad']	New Economic Policy of India; Kerala Swasraya Samithi; Kerala Sasthra Sahithya Parishad
# dhooredhooredhoore1990prmadhavapanicker	ദൂരെ ദൂരെ ദൂരെ -  പി.ആർ. മാധവപ്പണിക്കർ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	['kssp-science books', 'P R Madhavappanikkar', 'Malayalam Physics Books']	kssp-science books; P R Madhavappanikkar; Malayalam Physics Books
# ekmdistliteracy1990kssp	Ernakulam District Total Literarcy Project - A Report - Kerala Sastra Sahithya Parishad	['Ernakulam District Total Literarcy Programme', 'Kerala Literacy']	Ernakulam District Total Literarcy Programme; Kerala Literacy
# eurekakalikal1992kssp	യുറീക്കാ ശാസ്ത്രക്കളികൾ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Science Education	Science Education
# eurekamagazinevo0000kssp	യുറീക്ക - കുട്ടികളുടെ ശാസ്ത്രമാസിക - 1970 ജൂൺ - വാല്യം 1 ലക്കം 1	Eureka Magazine, Malayalam Children's Magazine	Eureka Magazine; Malayalam Children's Magazine
# eurekamagazinevo0000kssp_b8f9	യുറീക്ക - കുട്ടികളുടെ ശാസ്ത്രമാസിക - 1970 ജൂലായ് - വാല്യം 1 ലക്കം 2	Eureka Magazine	Eureka Magazine
# expresshway2004kssp	എക്സ്പ്രസ്സ് ഹൈവേ - ജലനിധി - ചെറുത്തു തോൽപ്പിക്കേണ്ട രണ്ട് വികസന വിരുദ്ധ പദ്ധതികൾ	Kerala Development, Express Highway, Jalanidhi	Kerala Development; Express Highway; Jalanidhi
# ezhuthupusthakam1989kssp	അക്ഷരം - എഴുത്തുപുസ്തകം - എറണാകുളം ജില്ല സമ്പൂർണ്ണ സാക്ഷരതായജ്ഞം	['Ernakulam District Total Literarcy Programme', 'Kerala Literacy']	Ernakulam District Total Literarcy Programme; Kerala Literacy
# ganithamekmlit1989kssp	ഗണിതം - അധ്യാപനസഹായി - എറണാകുളം ജില്ല സമ്പൂർണ്ണ സാക്ഷരതായജ്ഞം	['Ernakulam District Total Literarcy Programme; Mathematics Hand Book', 'Kerala Literacy']	Ernakulam District Total Literarcy Programme; Mathematics Hand Book; Kerala Literacy
# gattumnayangalum1994kssp	ഗാട്ടും പുത്തൻ സാമ്പത്തിക നയങ്ങളും - കുറെ ചോദ്യങ്ങളും ഉത്തരങ്ങളും – കേരള സ്വാശ്രയ സമിതി	['Globalization, Gatt Agreement', 'Kerala Swashraya Samithy']	Globalization; Gatt Agreement; Kerala Swashraya Samithy
# geethangal1980kssp	ഗീതങ്ങൾ - ശാസ്ത്രകലാജാഥ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	['Sasthra Kala Jatha', 'Kerala Archives']	Sasthra Kala Jatha; Kerala Archives
# gramavikasanarekha1984kssp	1984 - ഗ്രാമവികസനം - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Kerala Economy, Rural Development	Kerala Economy; Rural Development
# hallydhumakethu1986kssp	ഹാലി ധൂമകേതുവിനു സ്വാഗതം - നക്ഷത്രക്കുറിപ്പുകൾ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Astronomy, Halley's comet	Astronomy; Halley's comet
# indiayerakshikkan1992kssp	ഇന്ത്യയെ രക്ഷിക്കാൻ – കേരള സ്വാശ്രയ സമിതി	['Globalization, Dunkal Draft, Indian Economy', 'Kerala Swashraya Samithy']	Globalization; Dunkal Draft; Indian Economy; Kerala Swashraya Samithy
# irupathonnamnutandu1986kssp	ഇരുപത്തൊന്നാം നൂറ്റാണ്ടിലേക്ക് - ഗാനങ്ങളും സംഗീതശില്പങ്ങളും നാടകങ്ങളും - ശാസ്ത്രസാംസ്കാരികജാഥ 1986 - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Sasthra Kala Jatha, Street Theatre	Sasthra Kala Jatha; Street Theatre
# isrocharacase1995kssp	ഇന്ത്യൻ ബഹിരാകാശ ഗവേഷണം ചാരവൃത്തിക്കു മുമ്പും പിമ്പും - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	['ISRO; KSSP leaflets', 'Kerala Archives']	ISRO; KSSP leaflets; Kerala Archives
# janakeeyasasthraprasthanam1992kssp	ജനകീയ ശാസ്ത്രപ്രസ്ഥാനം വിശാലമാക്കുന്ന പ്രവർത്തന മേഖലകൾ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	People's Science Movement in Kerala	People's Science Movement in Kerala
# janakeeyasuthranavivadam2003kssp	ജനകീയാസൂത്രണ വിവാദം - ശാസ്ത്രസാഹിത്യ പരിഷത്തിന് പറയാനുള്ളത്	People's Planning	People's Planning
# janakiyasuthranam2002kssp	ജനകീയാസൂത്രണം - അനുഭവങ്ങളും അടിയന്തര കടമകളും - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	People's Planning; Participative Democracy, Decentralization	People's Planning; Participative Democracy; Decentralization
# janangal1989kssp	ജനങ്ങൾ സാക്ഷരരാകുന്നതെന്തിന് - സി.ജി. ശാന്തകുമാർ	['Education, Literacy', 'Kerala Literacy']	Education; Literacy; Kerala Literacy
# jwala0000kssp	ജ്വാല - ശാസ്ത്രഗീതങ്ങൾ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Bhopal Gas Tragedy	Bhopal Gas Tragedy
# kalarppuvasthukkal0000kssp	കലർപ്പുവസ്തുക്കളും കണ്ടുപിടിക്കുന്നതിനുള്ള മാർഗ്ഗങ്ങളും - ഗ്രാമശാസ്ത്രജാഥ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Science Education, Adulteration	Science Education; Adulteration
# kalikkamaravindgupta1990kssp	കളിക്കാം പഠിക്കാം - അരവിന്ദ് ഗുപ്ത	Malayalam Science Education Books	Malayalam Science Education Books
# 'subject'
# kalikoottam1992kssp	കളിക്കൂട്ടം - കുട്ടികളുടെ ഒഴിവുകാല പരിപാടി - പ്രവർത്തകർക്കുള്ള കുറിപ്പുകൾ	False
# kalivela2002kssp	2002 - കളിവേള - ബാലവേദി കൈപുസ്തകം - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	['KSSP leaflets', 'Kerala Archives']	KSSP leaflets; Kerala Archives
# kallukalkrama1979kssp	കല്ലുകൾ കഥ പറയുന്നു - കെ. രാമചന്ദ്രൻ	['Parishath Geology Books, Rock', 'KSSP Books']	Parishath Geology Books; Rock; KSSP Books
# kannethathaprmad1983kssp	കണ്ണെത്താത്ത ദൂരങ്ങളിൽ - പി.ആർ. മാധവപണിക്കർ	Astronomy, Cosmology	Astronomy; Cosmology
# kanyabhoomi1990kssp	കന്യാഭൂമി - സംഗീത ശിൽപങ്ങളും നാടകങ്ങളും - ഭാരത വിജ്ഞാൻ സമിതി	['Bharat Gyanvigyan Samithi Kerala, Street Theatre in Kerala, Literacy, Gender', 'Kerala Sasthra Sahithya Parishad', 'Kerala Archives']	Bharat Gyanvigyan Samithi Kerala; Street Theatre in Kerala; Literacy; Gender; Kerala Sasthra Sahithya Parishad; Kerala Archives
# kariyunnakalpavriksham1984kssp	കരിയുന്ന കല്പവൃക്ഷം - എം.പി. പരമേശ്വരൻ, ടി.എം. തോമസ് ഐസക്ക്	Kerala Coconut Industry; KSSP leaflets	Kerala Coconut Industry; KSSP leaflets
# karshikameghala1993kssp	പുത്തൻ സാമ്പത്തിക പരിഷ്കാരങ്ങളും കാർഷിക മേഖലയും - കേരള സ്വാശ്രയ സമിതി	['Dunkal Draft, New Economic Policy, Agriculture', 'Kerala Swashraya Samithy']	Dunkal Draft; New Economic Policy; Agriculture; Kerala Swashraya Samithy
# kavimalika1986kssp	കവിമാലിക - സംഗീതശില്പം - ശാസ്ത്രസാംസ്കാരികജാഥ 1986 - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Kala Jatha, Street Theatre	Kala Jatha; Street Theatre
# kayalnammude1991kssp	കായൽ നമ്മുടെ സമ്പത്ത് - കായൽ സംരക്ഷണ ജാഥ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Kala Jatha, Ecology	Kala Jatha; Ecology
# keralapanchayathraj1995kssp	കേരള പഞ്ചായത്ത് രാജ് നിയം 1994 - ഒരു വിലയിരുത്തൽ	Kerala Panchayathraj	Kerala Panchayathraj
# keralathilevidyabhyasam1994kssp	കേരളത്തിലെ വിദ്യാഭ്യാസം - പ്രശ്നങ്ങളും കടമകളും - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Education	Education
# keralathintesampathu1984edn6kssp	1984 - കേരളത്തിന്റെ സമ്പത്തു് - ആറാം പതിപ്പ് - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	KSSP General Documents	KSSP General Documents
# keralathinuoruar0000kssp	കേരളത്തിന് ഒരു ആരോഗ്യനയം - ചർച്ചക്കുള്ള കുറിപ്പുകൾ	KSSP leaflets;KSSP Health Books;Kerala Health Books	KSSP leaflets; KSSP Health Books; Kerala Health Books
# keralavikasanam0000kssp	കേരളം ഒരു വികസന പരിപ്രേക്ഷ്യം - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	['Development, Decentralization', 'Kerala Archives']	Development; Decentralization; Kerala Archives
# keramulamkadukal0000kssp	കേരളത്തിലെ മുളങ്കാടുകൾ - ഒരു ശാസ്ത്രീയ സമീപനത്തിന്റെ ആവശ്യകത	['Bamboo', 'Kerala Environment']	Bamboo; Kerala Environment
# kilikoottam0000kssp	കിളിക്കൂട്ടം - ഗാനങ്ങൾ, നാടകങ്ങൾ - ജാഥാ സ്ക്രിപ്റ്റ് - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Kala Jatha, Street Theatre	Kala Jatha; Street Theatre
# 'subject'
# kssp-archives	Kerala Sasthra Sahithya Parishad	False
# kssp-inaguration1962kssp	1962 - കേരള ശാസ്ത്രസാഹിത്യപരിഷത്ത് രൂപീകരണ പത്രവാർത്തകൾ	news kssp-inaguration	news kssp-inaguration
# ksspsilentvalley0000kssp	1979 - സൈലന്റ്‌വാലി പദ്ധതി - ഒരു സാങ്കേതിക- പാരിസ്ഥിതിക-സാമൂഹ്യ-രാഷ്ട്രീയ പഠനം	KSSP leaflets; Silent Valley	KSSP leaflets; Silent Valley
# ksspsouvenir1983kssp	1983 - കേരള ശാസ്ത്ര സാഹിത്യ പരിഷത്ത് 20-ാം വാർഷികം - സുവനീർ	KSSP Souvenir	KSSP Souvenir
# ksspurjapathisan0000kssp	1992 - കേരളത്തിന്റെ ഊർജപ്രതിസന്ധിയും കായം‌കുളം താപനിലയവും	KSSP leaflets, Power Problem in Kerala, Kayamkulam Thermal Station KSSP Books about Energy	KSSP leaflets; Power Problem in Kerala; Kayamkulam Thermal Station KSSP Books about Energy
# kushtaraogam0000kssp	കുഷ്ഠരോഗത്തെ മനസ്സിലാക്കുക - ഗ്രാമശാസ്ത്രജാഥ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Health, leprosy	Health; leprosy
# leadkindlylight1989kssp	Lead Kindly Light - Ernakulam District Literacy Programme	['Ernakulam District Total Literarcy Programme', 'Kerala Literacy']	Ernakulam District Total Literarcy Programme; Kerala Literacy
# mahothsavam1997kssp	മഹോത്സവം - സമത കലാജാഥ 1997 സ്ക്രിപ്റ്റുകൾ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Kala Jatha, Street Theatre	Kala Jatha; Street Theatre
# mamsamthinnunnasasyangal0000kssp	മാംസം തിന്നുന്ന സസ്യങ്ങൾ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	carnivorous plants	carnivorous plants
# manushyankatha1989ekmlit	മനുഷ്യൻ മനുഷ്യനായ കഥ - അധ്യാപനസഹായി - എറണാകുളം ജില്ല സമ്പൂർണ്ണ സാക്ഷരതായജ്ഞം	['History', 'Ernakulam District Total Literarcy Programme']	History; Ernakulam District Total Literarcy Programme
# maramparanja0000kssp	ഒരു മരം പറഞ്ഞ കഥ - ഗ്രാമശാസ്ത്രജാഥ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Environment	Environment
# marichavareadakal1984kssp	മരിച്ചവരെ അടക്കൽ - നാടകങ്ങൾ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Kala Jatha, Street Theatre	Kala Jatha; Street Theatre
# medicalsamaram0000ekba	മെഡിക്കൽ സമരം ഉയർത്തിയ പ്രശ്നങ്ങൾ - ഡോ: ബി. ഇക്ബാൽ	KSSP leaflets;KSSP Health Books	KSSP leaflets; KSSP Health Books
# mochanam1982kssp	മോചനം -  ശാസ്ത്രകലാജാഥ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Sasthra Kala Jatha, Street Theatre	Sasthra Kala Jatha; Street Theatre
# mollakkayudekuthira1987kssp	മൊല്ലാക്കയുടെ കുതിര - പാവനാടകങ്ങൾ - ബാലോത്സവജാഥ 1987 - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Sasthra Kala Jatha, Street Theatre	Sasthra Kala Jatha; Street Theatre
# nadakangal1981kssp	വെളിച്ചത്തിലേക്ക്, ആഫീസ് (നാടകങ്ങൾ) - ശാസ്ത്രകലാജാഥ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	['Sasthra Kala Jatha, Street Theatre', 'Kerala Archives']	Sasthra Kala Jatha; Street Theatre; Kerala Archives
# nadakasilpasala0000kssp	ബഹുജന നാടക പ്രസ്ഥാനം ശിൽപ്പശാല - കുറിപ്പുകൾ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Street Theatre	Street Theatre
# naleyudempp1983kssp	നാളെയുടെ വാഗ്ദാനം - എം.പി. പരമേശ്വരൻ	['politics', 'KSSP Books']	politics; KSSP Books
# nallanaale1989ekmlit	നല്ലനാളെ - അധ്യാപനസഹായി - എറണാകുളം ജില്ല സമ്പൂർണ്ണ സാക്ഷരതായജ്ഞം	['KSSP- Health Education Books; Ernakulam District Total Literarcy Programme', 'Ernakulam District Total Literarcy Programme']	KSSP- Health Education Books; Ernakulam District Total Literarcy Programme; Ernakulam District Total Literarcy Programme
# nammalariyan2000kssp	നമ്മളറിയാൻ - ആഗോളവൽക്കരണത്തിനെതിരെ ജനജാഗ്രത	Globalization	Globalization
# nammalonnu1986kssp	നമ്മളൊന്ന് - ഗാനങ്ങളും സംഗീതശില്പങ്ങളും - ശാസ്ത്രകലാജാഥ 1986 - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Kala Jatha, Street Theatre	Kala Jatha; Street Theatre
# namukkuchuttumullalokam1989kssp	നമുക്കു ചുറ്റുമുള്ള ലോകം - അധ്യാപനസഹായി - എറണാകുളം ജില്ല സമ്പൂർണ്ണ സാക്ഷരതായജ്ഞം	Ernakulam District Total Literarcy Programme; Malayalam Science Books	Ernakulam District Total Literarcy Programme; Malayalam Science Books
# narakam1981kssp	നരകം (നാടകം) - ശാസ്ത്രകലാജാഥ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	['Sasthra Kala Jatha, Street Theatre', 'Kerala Archives']	Sasthra Kala Jatha; Street Theatre; Kerala Archives
# navamalika1987kssp	നവമാലിക - സംഗീതശില്പം- ശാസ്ത്രസാംസ്കാരികജാഥ 1987 - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Sasthra Kala Jatha, Street Theatre	Sasthra Kala Jatha; Street Theatre
# njansthree1990kssp	ഞാൻ സ്ത്രീ - വനിതാകലാജാഥാ സ്ക്രിപ്റ്റുകൾ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Kala Jatha, Street Theatre	Kala Jatha; Street Theatre
# onnaampadam1995kssp	ഒന്നാം പാഠം - വിദ്യാഭ്യാസ ജാഥാ സ്ക്രിപ്റ്റുകൾ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Kala Jatha, Street Theatre, Kerala Education	Kala Jatha; Street Theatre; Kerala Education
# orudheeraswapnam1994kssp	ഒരു ധീര സ്വപ്നം -  ശാസ്ത്രകലാജാഥാ സ്ക്രിപ്റ്റുകൾ - ശാസ്ത്ര സാംസ്കാരിക ജാഥ 1994 - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Sasthra Kala Jatha, Street Theatre	Sasthra Kala Jatha; Street Theatre
# orukunjujanikkunnu0000kssp	ഒരു കുഞ്ഞ് ജനിക്കുന്നു - ഗ്രാമശാസ്ത്രജാഥ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Reproduction, Sex Education	Reproduction; Sex Education
# orumaramoruvaram1987kssp	ഒരു മരം ഒരു വരം - പാവനാടകങ്ങൾ - ബാലോത്സവജാഥ 1987 - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Balalsava Jatha, Street Theatre	Balalsava Jatha; Street Theatre
# othukali1984kssp	ഒത്തുകളി - ദേശീയ കലാരൂപങ്ങൾ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Kala Jatha, Street Theatre	Kala Jatha; Street Theatre
# ottanthullalukal1980kssp	ഓട്ടൻതുള്ളലുകൾ - ശാസ്ത്രകലാജാഥ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	['Sasthra Kala Jatha, Street Theatre', 'Kerala Archives']	Sasthra Kala Jatha; Street Theatre; Kerala Archives
# padanolsavam1998kssp	പഠനോത്സവം - ക്ലാസെടുക്കുന്നവർക്കുള്ള കുറിപ്പുകൾ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Development	Development
# panayapeduthiyabhavi1992kssp	പണയപ്പെടുത്തിയ ഭാവി വീണ്ടെടുക്കാൻ - കേരള സ്വാശ്രയ സമിതി	['Kerala Swasraya Samithi, Economic Policy', 'Kerala Swashraya Samithy']	Kerala Swasraya Samithi; Economic Policy; Kerala Swashraya Samithy
# papi1981kssp	പാപി (വിൽപാട്ട്) - ശാസ്ത്രകലാജാഥ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	['Sasthra Kala Jatha, Street Theatre', 'Kerala Archives']	Sasthra Kala Jatha; Street Theatre; Kerala Archives
# parishathaduppu0000kssp	പരിഷത്തടുപ്പ് - പ്രവർത്തകരുടെ കൈപ്പുസ്തകം	KSSP leaflets;Parishathaduppu	KSSP leaflets; Parishathaduppu
# parishathenthucheyyunnu0000kssp	പരിഷത്ത് എന്തു ചെയ്യുന്നു? - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	["People's science movement", 'Kerala Archives']	People's science movement; Kerala Archives
# parisheelanarekha1981kssp	1981 - പ്രവർത്തക പരിശീലന രേഖ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	["People's science movement", 'Kerala Archives']	People's science movement; Kerala Archives
# parisheelanarekha1982kssp	1982 - പ്രവർത്തക പരിശീലന രേഖ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	["KSSP Cadre Education, People's Science Movement", 'Kerala Archives']	KSSP Cadre Education; People's Science Movement; Kerala Archives
# paristhathaduppu0000kssp	1990 - പരിഷത്തടുപ്പ്	KSSP leaflets;Parishathaduppu	KSSP leaflets; Parishathaduppu
# pattukal1980kssp	പാട്ടുകൾ - ശാസ്ത്രകലാജാഥ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	KSSP Songs	KSSP Songs
# pavanadakangal1988kssp	പാവനാടകങ്ങൾ  - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Sasthra Kala Jatha, Street Theatre, Puppetry Script	Sasthra Kala Jatha; Street Theatre; Puppetry Script
# penakalkadha1990kssp	പേനകൾ കഥ പറയുന്നു - സംഗീത ശിൽപങ്ങളും നാടകങ്ങളും - ഭാരത വിജ്ഞാൻ സമിതി	['Bharat Gyanvigyan Samithi Kerala, Street Theatre in Kerala, Literacy, Gender', 'Kerala Sasthra Sahithya Parishad', 'Kerala Archives']	Bharat Gyanvigyan Samithi Kerala; Street Theatre in Kerala; Literacy; Gender; Kerala Sasthra Sahithya Parishad; Kerala Archives
# petamma1995kssp	പെറ്റമ്മ - വിദ്യാഭ്യാസ ജാഥാ സ്ക്രിപ്റ്റുകൾ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Kala Jatha, Street Theatre	Kala Jatha; Street Theatre
# pkdjillavikasana1981kssp	1981 - പാലക്കാട് ജില്ല വികസന രേഖ	['Development Palakkad', 'Kerala Development']	Development Palakkad; Kerala Development
# prathirodham0000kssp	പ്രതിരോധ കുത്തിവെപ്പുകൾ - ഗ്രാമശാസ്ത്രജാഥ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	vaccination	vaccination
# punyabhumiyudethengal1992kssp	പുണ്യഭൂമിയുടെ തേങ്ങൽ - ഗാനങ്ങൾ, സംഗീത ശില്പങ്ങൾ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Kala Jatha, Street Theatre	Kala Jatha; Street Theatre
# puthanpattukar1987kssp	പുത്തൻ പാട്ടുകാർ - ശാസ്ത്രസാംസ്കാരികജാഥ 1987 - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Sasthra Kala Jatha, Street Theatre	Sasthra Kala Jatha; Street Theatre
# puthiyapadypadhathi1999kssp	പുതിയ പാഠ്യപദ്ധതി - വിമർശനങ്ങളും വസ്തുതകളും - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Education	Education
# saksharathayanjamrandam1991kssp	അക്ഷരകേരളം - സാക്ഷരതായജ്ഞം രണ്ടാം ഘട്ടം - ഇൻസ്ട്രക്റ്റർമാർക്കുള്ള കുറിപ്പുകൾ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Education, Literacy	Education; Literacy
# samathalam1981kssp	സമതലം (നാടകം) - ശാസ്ത്രകലാജാഥ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	['Sasthra Kala Jatha, Street Theatre', 'Kerala Archives']	Sasthra Kala Jatha; Street Theatre; Kerala Archives
# samathavinjanotsavam1997kssp	സമത വിജ്ഞാനോത്സവം - പരിശീലകർക്കുള്ള കൈപുസ്തകം - ഭാരത വിജ്ഞാൻ സമിതി	['Bharat Gyanvigyan Samithi Kerala, Samatha Vijnanolsavam, Gender', 'Kerala Sasthra Sahithya Parishad', 'Kerala Archives']	Bharat Gyanvigyan Samithi Kerala; Samatha Vijnanolsavam; Gender; Kerala Sasthra Sahithya Parishad; Kerala Archives
# samoohyamanushyanum1982kssp	സാമൂഹ്യമനുഷ്യനും പ്രപഞ്ചവും - ശാസ്ത്രപാഠാവലി - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Science Education	Science Education
# sampathikaparishkaram1991kssp	പുതിയ സാമ്പത്തിക പരിഷ്കാരങ്ങളും പ്രത്യാഘാതങ്ങളും - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	['Globalization, New Economic Policy', 'Kerala Archives']	Globalization; New Economic Policy; Kerala Archives
# samrajyatham1992kssp	സാമ്രാജ്യത്വം ഇന്നലെ, ഇന്ന് – കേരള സ്വാശ്രയ സമിതി	['Imperialism, Globalization', 'Kerala Swashraya Samithy']	Imperialism; Globalization; Kerala Swashraya Samithy
# santhigeetham1987kssp	ശാന്തിഗീതം - ഗാനങ്ങൾ  - ശാസ്ത്ര സാംസ്കാരിക ജാഥ 1987 - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Kala Jatha, Street Theatre	Kala Jatha; Street Theatre
# sasthragathifeb1968kssp	ശാസ്ത്രഗതി - ലക്കം 4 - 1968 ഫെബ്രുവരി	Sasthragathi	Sasthragathi
# sasthragathijan1967kssp	ശാസ്ത്രഗതി ലക്കം 2 - 1967 ജനുവരി- കേരള ശാസ്ത്രസാഹിത്യപരിഷത്ത്	Sasthragathi	Sasthragathi
# sasthragathijuly1967kssp	ശാസ്ത്രഗതി - ലക്കം 3 - 1967 ജൂലൈ - കേരള ശാസ്ത്രസാഹിത്യപരിഷത്ത്	['Malayalam Science Magazine', 'Sasthragathi']	Malayalam Science Magazine; Sasthragathi
# sasthrageethika1984kssp	ശാസ്ത്രഗീതിക - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Kala Jatha, Street Theatre	Kala Jatha; Street Theatre
# sasthragitha0000kssp	ശാസ്ത്രഗീത - ഗ്രാമശാസ്ത്രജാഥ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Grama Sasthra Jatha	Grama Sasthra Jatha
# sasthrakeralam0000kssp	ശാസ്ത്രകേരളം - സയൻസു മാസിക - ലക്കം 1 - 1969 ജൂൺ	Sasthra Keralam Magazine, Malayalam Science Magazine	Sasthra Keralam Magazine; Malayalam Science Magazine
# sasthrakeralammay1974kssp	ശാസ്ത്രകേരളം - സയൻസു മാസിക - 1974 മെയ്	Sasthra Keralam Magazine	Sasthra Keralam Magazine
# sasthramgramangalkku1982kssp	1982 - ഗ്രാമ ശാസ്ത്രജാഥ - ശാസ്ത്രം ഗ്രാമങ്ങൾക്ക് - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Grama Sasthra Jatha	Grama Sasthra Jatha
# sasthramgrameenarkku1983kssp	1983 - ഗ്രാമ ശാസ്ത്രജാഥ - ശാസ്ത്രം ഗ്രാമീണർക്ക് - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Grama Sasthra Jatha	Grama Sasthra Jatha
# sasthraparimathru2001kssp	2001 - ശാസ്ത്രസാഹിത്യപരിഷത്ത് പിറക്കുന്നു - ഡോ. കെ.ജി. അടിയോടി	K.G. Adiyodi	K.G. Adiyodi
# sasthrapariulgha1962kssp	1962 - ശാസ്ത്രസാഹിത്യപരിഷത്ത് - ഉൽഘാടനസ്മാരകം	['KSSP Souvenir', 'KSSP General Documents']	KSSP Souvenir; KSSP General Documents
# sasthrasankethika1993kssp	ഇന്ത്യയുടെ ശാസ്ത്രസാങ്കേതിക രംഗം നേരിടുന്ന പുത്തൻ വെല്ലുവിളികൾ – കേരള സ്വാശ്രയ സമിതി	['Science and Technology Policy', 'Kerala Swashraya Samithy']	Science and Technology Policy; Kerala Swashraya Samithy
# seetha1985kssp	സീത - ഗാനങ്ങളും നാടകങ്ങളും സംഗീതശില്പങ്ങളും - ശാസ്ത്രകലാജാഥ 1985 - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Sasthra Kala Jatha, Street Theatre	Sasthra Kala Jatha; Street Theatre
# sevanamekhala1993kssp	സേവന മേഖലക്കുമേൽ സാമ്രാജ്യത്വ നീരാളിപ്പിടുത്തം - കേരള സ്വാശ്രയ സമിതി	['Kerala Swasraya Samithi, Globalization, Indian Economy', 'Kerala Swashraya Samithy']	Kerala Swasraya Samithi; Globalization; Indian Economy; Kerala Swashraya Samithy
# silentvalleychar0000kssp	സൈലന്റ്‌വാലി ചർച്ച	KSSP leaflets; Silent Valley; KSSP Ecology Books	KSSP leaflets; Silent Valley; KSSP Ecology Books
# silentvalleyjala0000kssp	സൈലന്റ്‌വാലി ജലവൈദ്യുതപദ്ധതി - കേരള സ്റ്റേറ്റ് ഇലക്ട്രിസിറ്റി ബോർഡ്	KSSP leaflets;Silent Valley	KSSP leaflets; Silent Valley
# silentvalleypari0000kssp	1980 - സൈലന്റ്‌വാലി പദ്ധതി - പരിഷത്തിന്റെ നിലപാടും വിശദീകരണവും	KSSP leaflets;Silent Valley	KSSP leaflets; Silent Valley
# sisuvidyabhyasam1999kssp	ശിശുവിഭ്യാഭ്യാസം - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Education	Education
# soapinterast2001kssp	2001 - സോപ്പിന്റെ ശാസ്ത്രവും രാഷ്ട്രീയവും	Science Education, Soap, Indian Soap Industry	Science Education; Soap; Indian Soap Industry
# souraaduppu0000pgpa	1981 - സൗര അടുപ്പ് - പി.ജി. പത്മനാഭൻ	KSSP leaflets, KSSP energy Books	KSSP leaflets; KSSP energy Books
# spartacs1981kssp	സ്‌പാർട്ടക്കസ് (കഥാപ്രസംഗം) - ശാസ്ത്രകലാജാഥ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	['Sasthra Kala Jatha,', 'Kerala Archives']	Sasthra Kala Jatha; ; Kerala Archives
# stateconventiono0000kssp	State Convention of Modern Medical Doctors - Draft Manifesto for Discussion	KSSP leaflets;KSSP Health Books;Modern Medical Doctors	KSSP leaflets; KSSP Health Books; Modern Medical Doctors
# sthreekalumpinth0000sama	സ്ത്രീകളും പിന്തുടർച്ചാവകാശവും - സമതാവേദി	KSSP leaflets; Samatha leaflets, Gender Bias in Kerala	KSSP leaflets; Samatha leaflets; Gender Bias in Kerala
# sthreekalumsaksh0000kssp	സ്ത്രീകളും സാക്ഷരതയും (ചർച്ചയ്ക്കുള്ള കുറിപ്പ്)	KSSP leaflets;KSSP Gender Books;Gender Bias in Kerala	KSSP leaflets; KSSP Gender Books; Gender Bias in Kerala
# suryanteathmakadha1979kssp	സൂര്യന്റെ ആത്മകഥ - വി.കെ. ദാമോദരൻ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Sun, Energy	Sun; Energy
# susthiravikasanamjankeeya2018kssp	സുസ്ഥിര വികസനം സുരക്ഷിത കേരളം - ജനകീയ ക്യാമ്പയിൻ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Development, Flood 2018, Climate Change	Development; Flood 2018; Climate Change
# swasryakalajatha0000kssp	സ്വാശ്രയ കലാ ജാഥ - നാടകങ്ങൾ, ഗാനങ്ങൾ, സംഗീതശിൽപങ്ങൾ - കേരള സ്വാശ്രയ സമിതി - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Kala Jatha, Street Theatre	Kala Jatha; Street Theatre
# thengumvazhayum0000kssp	തെങ്ങും വാഴയും - ഗ്രാമശാസ്ത്രജാഥ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Agriculture, Banana, Coconut	Agriculture; Banana; Coconut
# thiricharivu1989kssp	തിരിച്ചറിവ് - വനിതാകലാജാഥാ സ്ക്രിപ്റ്റുകൾ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Kala Jatha, Street Theatre	Kala Jatha; Street Theatre
# thudarsaksharatha1992kssp	തുടർസാക്ഷരത - എന്തിന്? എന്ത്? എങ്ങനെ? - പ്രവർത്തകർക്കുള്ള കൈപുസ്തകം	['Kerala Literacy, Education', 'Kerala Literarcy']	Kerala Literacy; Education; Kerala Literarcy
# unarthupaatu1989kssp	ഉണർത്തുപാട്ട് - വനിതാകലാജാഥാ സ്ക്രിപ്റ്റുകൾ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Kalajatha, Street Drama	Kalajatha; Street Drama
# unnathavidyabhyasa1999kssp	1999 - ഉന്നത വിദ്യാഭ്യാസരംഗത്തെ പ്രശ്നങ്ങൾ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	['Higher Education Kerala', 'Kerala Education']	Higher Education Kerala; Kerala Education
# urjamchodyothara0000kssp	ഊർജം - ചോദ്യോത്തരങ്ങൾ	KSSP leaflets;Kerala Energy	KSSP leaflets; Kerala Energy
# vanagatha0000kssp	വനഗാഥ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Kala Jatha, Street Theatre, Kerala Environment	Kala Jatha; Street Theatre; Kerala Environment
# vanaparvam1981kssp	വനപർവം (കക്കാരിശി നാടകം) - ശാസ്ത്രകലാജാഥ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	['Sasthra Kala Jadha, Street Theatre', 'Kerala Archives']	Sasthra Kala Jadha; Street Theatre; Kerala Archives
# vanitharekha1987kssp	1987 - പരിഷത്തും സ്ത്രീപ്രശ്നവും - വനിതാരേഖ	Gender	Gender
# vayarilakkam0000kssp	വയറുകടിയും വയറിളക്കവും - ഗ്രാമശാസ്ത്രജാഥ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Health Education, Dysentery	Health Education; Dysentery
# vayarilakkamchar0000rajm	വയറിളക്കം ഛർദി അതിസാരം - ഡോ. കെ. രാജ്മോഹൻ	KSSP leaflets;KSSP Health Books	KSSP leaflets; KSSP Health Books
# velichamenayi1989kssp	വെളിച്ചമേ നയിച്ചാലും - എറണാകുളം ജില്ല സമ്പൂർണ്ണ സാക്ഷരതായജ്ഞം	['Ernakulam District Total Literarcy Programme', 'Kerala Literacy']	Ernakulam District Total Literarcy Programme; Kerala Literacy
# velichamenayicha1989kssp	വെളിച്ചമേ നയിച്ചാലും - എറണാകുളം ജില്ല സമ്പൂർണ്ണ സാക്ഷരതായജ്ഞം	['Ernakulam District Total Literarcy Programme', 'Kerala Literacy']	Ernakulam District Total Literarcy Programme; Kerala Literacy
# velichathilekku1989kssp	വെളിച്ചത്തിലേയ്ക്ക് - എറണാകുളം ജില്ല സമ്പൂർണ്ണ സാക്ഷരതായജ്ഞം	['Ernakulam District Total Literarcy Programme', 'Kerala Literacy']	Ernakulam District Total Literarcy Programme; Kerala Literacy
# vidyapari2007kssp	2007 - വിദ്യാഭ്യാസ പരിഷ്ക്കാരങ്ങൾ - വിമർശനങ്ങളുടെ നേരും നുണയും	['Education', 'Kerala Education']	Education; Kerala Education
# vidyaparvam1995kssp	വിദ്യാപർവ്വം - വിദ്യാഭ്യാസ ജാഥാ സ്ക്രിപ്റ്റുകൾ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Kala Jatha, Street Theatre	Kala Jatha; Street Theatre
# vikasanajatha1998kssp	വികസന ജാഥ - 98	People's Planning; decentralization	People's Planning; decentralization
# vikasanamjanangal1989ekmlit	വികസനവും ജനങ്ങളും - അധ്യാപനസഹായി - എറണാകുളം ജില്ല സമ്പൂർണ്ണ സാക്ഷരതായജ്ഞം	['Government welfare schemes in Kerala', 'Ernakulam District Total Literarcy Programme']	Government welfare schemes in Kerala; Ernakulam District Total Literarcy Programme
# vikendreekrithaasoothranam0000kssp	വികേന്ദ്രീകൃത ആസൂത്രണം - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	['Decentralization, Planning', 'Kerala Archives']	Decentralization; Planning; Kerala Archives
# vilapesal1983kssp	വിലപേശൽ - ശാസ്ത്രകലാജാഥാ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Sasthra Kala Jatha, Street Theatre	Sasthra Kala Jatha; Street Theatre
# vilpattukal1980kssp	വിൽപ്പാട്ടുകൾ - ശാസ്ത്രകലാജാഥ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Sasthra Kala Jatha, Street Theatre	Sasthra Kala Jatha; Street Theatre
# vilpattukaltest1980kssp	വിൽപ്പാട്ടുകൾ - ശാസ്ത്രകലാജാഥ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Kilipattu;  1982	Kilipattu; 1982
# vipanikal1994kssp	വിപണികൾ പൂക്കുന്നു -  ശാസ്ത്രകലാജാഥാ സ്ക്രിപ്റ്റുകൾ - ശാസ്ത്ര സാംസ്കാരിക ജാഥ 1994 - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Sasthra Kala Jatha, Street Theatre	Sasthra Kala Jatha; Street Theatre
# visittosilentval0000mssw	1979 - Report on the visit to the Silent Valley area of Kerala - M S Swaminathan	KSSP leaflets;Silent Valley	KSSP leaflets; Silent Valley
# vithuvaypa1993kssp	വിത്ത് മുതൽ വായ്പ വരെ – കേരള സ്വാശ്രയ സമിതി	['Kerala Swasraya Samithi, Indian Agriculture, Globalization', 'Kerala Swashraya Samithy']	Kerala Swasraya Samithi; Indian Agriculture; Globalization; Kerala Swashraya Samithy
# vyavasayameghala1992kssp	പുത്തൻ സാമ്പത്തിക പരിഷ്കാരങ്ങളും വ്യവസായ മേഖലയും - കേരള സ്വാശ്രയ സമിതി	['Globalization, Indian Industry', 'Kerala Swashraya Samithy']	Globalization; Indian Industry; Kerala Swashraya Samithy
# vyavasayamgramam1981kssp	1981 - വ്യവസായം ഗ്രാമങ്ങൾക്ക് - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	Village Industry, Rural Development	Village Industry; Rural Development
# vyavasayasouvenir1980kssp	1980 - വ്യവസായ സുവനീർ - കേരള ശാസ്ത്ര സാഹിത്യ പരിഷത്ത് 17-ാം വാർഷികം	KSSP Souvenir	KSSP Souvenir
# vyavasayavalkaranam1986kssp	വ്യവസായവല്ക്കരണം (ചോദ്യോത്തരങ്ങൾ)	Industrialisation of Kerala	Industrialisation of Kerala
# yudham1981kssp	യുദ്ധം (നാടകം) - ശാസ്ത്രകലാജാഥ - കേരള ശാസ്ത്രസാഹിത്യ പരിഷത്ത്	['Sasthra Kala Jatha, Street Theatre', 'Kerala Archives']	Sasthra Kala Jatha; Street Theatre; Kerala Archives

# %%
len(kssp)
# Out:
# 236

# %% [markdown]
# ## Normalizer
# This module normalizes current subject into the correct format expected by the archive.org website. Currently there are several non-standard forms there.
#
# Here are a few examples:
# ```
# 'Sasthra Kala Jatha, Street Theatre' # 'str', but comma seperated
# ['Kerala Swasraya Samithi, Indian Agriculture, Globalization', 'Kerala Swashraya Samithy'] # 'list', comma separated
# 'KSSP leaflets;KSSP Health Books;Modern Medical Doctors' # 'str', but no space between entries
# ```
#
# So before updating them with the new entries, we need to make sure that the subjects lines are formulated according to the standard format expeted by `archive.org` website.

# %%
subject_text = 'KSSP leaflets;KSSP Health Books;Modern Medical Doctors'
normalize_subject(subject_text)
# Out:
# KSSP leaflets; KSSP Health Books; Modern Medical Doctors

# %%
def normalize_subject(subject_text):
    if subject_text:
        if type(subject_text) == list:
            subject_text = ["; ".join(y.strip() for y in re.split(r'[;,]', x)) for x in subject_text]
            return("; ".join(subject_text))
        else:
            subject_text = re.split(r'[;,]', subject_text)
            subject_text = [x.strip() for x in subject_text]
            return("; ".join(subject_text))
    else:
        return ""

# %%
shiju_list = []
for i in search_items('uploader:shijualexonline@gmail.com'):
    shiju_list.append(i["identifier"])

# %%
shiju_list
# Out:
# ['1606_Synodo_Diocesano_Da_Igreia_E_Bispado',
#  '1732_Grammatica_Grandonica_Ernst_Hanxleden',
#  '1745_Historia_Ecclesiae_Malabarica_Cum_Diamper',
#  '1772AlphabetumGrandonicoMalabaricum',
#  '1787SaggioPraticoDelleLingue',
#  '1790_Siddharupam_Paulinus',
#  '1791_AlphabetaIndica_Paulinus',
#  '1791_Centum_Adagia_Malabarica_Paulinus',
#  '1797_Systema_Brahmanicum_Liturgicum_Mythologi_Paulinus',
#  '1799_Grammar_Of_The_MalabarLanguage',
#  '1811RambanBibleMalayalam',
#  '1813CMSMissionaryRegister',
#  '1814CMSMissionaryRegister',
#  '1815CMSMissionaryRegister',
#  '1815DissertationTheSecondOnTheMalayalmaLanguage',
#  '1816CMSMissionaryRegister',
#  '1817CMSMissionaryRegister',
#  '1818CMSMissionaryRegister',
#  '1819CMSMissionaryRegister',
#  '1820CMSMissionaryRegister',
#  '1821CMSMissionaryRegister',
#  '1822CMSMissionaryRegister',
#  '1823CMSMissionaryRegister',
#  '1824CMSMissionaryRegister',
#  '1824_Cheru_Paithangal',
#  '1825-Mathayiyude-evangeliyon',
#  '1825CMSMissionaryRegister',
#  '1826CMSMissionaryRegister',
#  '1827CMSMissionaryRegister',
#  '1828CMSMissionaryRegister',
#  '1829CMSMissionaryRegister',
#  '1829_Malayalam_NewTestament',
#  '1830CMSMissionaryRegister',
#  '1831CMSMissionaryRegister',
#  '1832CMSMissionaryRegister',
#  '1833CMSMissionaryRegister',
#  '1834_NewTestament_Malayalim_Language_Second_Edition',
#  '1835-first-lessons-cottayam-CMS',
#  '1835CMSMissionaryRegister',
#  '1836-ororuthan-cheyyendunna-prarthanakal',
#  '1836CMSMissionaryRegister',
#  '1837CMSMissionaryRegister',
#  '1838CMSMissionaryRegister',
#  '1839CMSMissionaryRegister',
#  '1839_The_Book_Of_Psalms_Malayalam',
#  '1839_The_Book_Of_Psalms_Malayalim',
#  '1839_Travancore_Calendar_for_1840',
#  '1840CMSMissionaryRegister',
#  '1840_Travancore_Calendar_for_1841',
#  '1840_onnam_chodyotharangalum_prarthanakalum',
#  '1841CMSMissionaryRegister',
#  '1841_A_Grammar_Of_The_Malayalim_Language',
#  '1842CMSMissionaryRegister',
#  '1842ChurchMissionaryGleanerVol2',
#  '1843CMSMissionaryRegister',
#  '1843ChurchMissionaryGleanerVol3',
#  '1843_Catechism_Malayalam_Basel_Mission',
#  '1843_Keralolpathi_Hermann_Gundert',
#  '1843_Malayalam_New_Testament',
#  '1844CMSMissionaryRegister',
#  '1845CMSMissionaryRegister',
#  '1846-Jnanakeertanangal',
#  '1846-apostolanaya-paulosinte-prasangam',
#  '1846CMSMissionaryRegister',
#  '1846ChurchMissionaryGleanerVol6',
#  '1846_Malayalam-English_Dictionary_Benjamin_Bailey',
#  '1847CMSMissionaryRegister',
#  '1847_Suvishesha_Kathakal',
#  '1848CMSMissionaryRegister',
#  '1848ChurchMissionaryGleanerVol8',
#  '1849ChurchMissionaryGleanerVol9',
#  '1849_English-Malayalim_Dictionary_Benjamin_Bailey',
#  '1850CMSMissionaryRegister',
#  '1850TheChurchMissionaryIntelligencer',
#  '1850_Orayiram_Pazhamchol_Hermann_Gundert',
#  '1850_Piyushasamgraham',
#  '1851CMSMissionaryRegister',
#  '1851TheChurchMissionaryGleanerNewSeriesVol1',
#  '1851TheChurchMissionaryIntelligencer',
#  '1851_Malayalam_Selections_A_J_Arbuthnot',
#  '1852CMSMissionaryRegister',
#  '1852TheChurchMissionaryGleanerNewSeriesVol2',
#  '1852TheChurchMissionaryIntelligencer',
#  '1853CMSMissionaryRegister',
#  '1853TheChurchMissionaryGleanerNewSeriesVol3',
#  '1853TheChurchMissionaryIntelligencer',
#  '1854CMSMissionaryRegister',
#  '1854TheChurchMissionaryGleanerNewSeriesVol4',
#  '1854TheChurchMissionaryIntelligencer',
#  '1855CMSMissionaryRegister',
#  '1855TheChurchMissionaryGleanerNewSeriesVol5',
#  '1855TheChurchMissionaryIntelligencer',
#  '1856-Jnanadeepasuchakam',
#  '1856TheChurchMissionaryGleanerNewSeriesVol6',
#  '1856TheChurchMissionaryIntelligencer',
#  '1856_Malayalam-English_Dictionary_E_Laseron',
#  '1856_The_Malayalam_Reader_Charles_Collett',
#  '1857TheChurchMissionaryGleanerNewSeriesVol7',
#  '1857TheChurchMissionaryIntelligencer',
#  '1858TheChurchMissionaryGleanerNewSeriesVol8',
#  '1858TheChurchMissionaryIntelligencer',
#  '1859TheChurchMissionaryAtlas',
#  '1859TheChurchMissionaryGleanerNewSeriesVol9',
#  '1859TheChurchMissionaryIntelligencer',
#  '1859_Kristhamargathinte_Upadesasamgraham',
#  '1859_Pointed_And_Unpointed_Romanic_Alphabets_J_G_Thompson',
#  '1860-an-anglo-malayalam-vocabulary-and-phrase-book',
#  '1860TheChurchMissionaryGleanerNewSeriesVol10',
#  '1860TheChurchMissionaryIntelligencer',
#  '1860_Pavithra_Charithram',
#  '1861-a-short-grammar-and-analysis-of-the-malayalim-language',
#  '1861-collection-of-terms-in-english-and-malayalim',
#  '1861TheChurchMissionaryGleanerNewSeriesVol11',
#  '1861TheChurchMissionaryIntelligencer',
#  '1862GramathiEnnaPusthakam',
#  '1862TheChurchMissionaryGleanerNewSeriesVol12',
#  '1862TheChurchMissionaryIntelligencer',
#  '1863TheChurchMissionaryGleanerNewSeriesVol13',
#  '1863TheChurchMissionaryIntelligencer',
#  '1864-nalla-edayante-anveshana-charithram',
#  '1864JulyVidyaSamgraham',
#  '1864JulyVidyaSamgrahamNo.IVol.1',
#  '1864OctoberVidyaSamgrahamVol.1No.2',
#  '1864TheChurchMissionaryGleanerNewSeriesVol14',
#  '1864TheChurchMissionaryIntelligencer',
#  '1865AprilVidyaSamgrahamVol.1No.4',
#  '1865JulyVidyaSamgrahamVol.1No.5',
#  '1865October_VidyaSamgraham_Vol.1_No.6',
#  '1865TheChurchMissionaryGleanerNewSeriesVol15',
#  '1865TheChurchMissionaryIntelligencer',
#  '1865_January_VidyaSamgraham_Vol.1_No.3',
#  '1866April_VidyaSamgraham_Vol.1_No.8',
#  '1866January_VidyaSamgraham_Vol.1_No.7',
#  '1866TheChurchMissionaryGleanerNewSeriesVol16',
#  '1866TheChurchMissionaryIntelligencer',
#  '1867TheChurchMissionaryGleanerNewSeriesVol17',
#  '1867_Catechism_Of_Malayalam_Grammar',
#  '1868TheChurchMissionaryGleanerNewSeriesVol18',
#  '1868TheChurchMissionaryIntelligencer',
#  '1868_Keralolpathi_Hermann_Gundert',
#  '1868_Malayalam_New_Testament_Hermann_Gundert',
#  '1868_Selection_Of_Official_Malayalam_Documents',
#  '1868_Selection_Of_Official_Malayalam_Documents_EnglishTranslation',
#  '1869ElementsOfEnglishGrammarInMalayalam',
#  '1869TheChurchMissionaryGleanerNewSeriesVol19',
#  '1869TheChurchMissionaryIntelligencer',
#  '1870TheChurchMissionaryGleanerNewSeriesVol20',
#  '1870TheChurchMissionaryIntelligencer',
#  '1870_Dhana_Thathwa_Nirupanam',
#  '1870_School_Dictionary_English_And_Malayalam',
#  '1871TheChurchMissionaryIntelligencer',
#  '1871_Prospectus_A_Malayalam_And_English_Dictionary',
#  '1872_An_Essay_On_The_Malabar_Syrian_Community_Rev.G_Curian',
#  '1872_Kurubana_Kramam',
#  '1873TheChurchMissionaryIntelligencer',
#  '1874TheChurchMissionaryIntelligencer',
#  '1875TheChurchMissionaryIntelligencer',
#  '1875_Ignatius_Peter_III_Kochi_Kota_Palli_Kalpana',
#  '1876TheChurchMissionaryIntelligencer',
#  '1876_Malayalam_New_Testament_Benjamin_Bailey',
#  '1877-a-vocabulary_malayalam-and-english',
#  '1877TheChurchMissionaryIntelligencer',
#  '1877_Ignatius_Peter_III_Kochi_Kota_Palli_Kalpana_Makaram_15',
#  '1877_Ignatius_Peter_III_Kochi_Kota_Palli_Kalpana_Makaram_27',
#  '1878KeralaKaumudi',
#  '1878TheChurchMissionaryGleaner',
#  '1878TheChurchMissionaryIntelligencer',
#  '1878TheGeographyOfTravancore',
#  '1879AMalayalamPoeticalAnthology',
#  '1879TheChurchMissionaryGleaner',
#  '1879TheChurchMissionaryIntelligencer',
#  '1879_Yakobaya_Suriyani_Sabhayude_Swaroopam',
#  '1880KristhaathmeeyaGeethangal',
#  '1880TheChurchMissionaryGleaner',
#  '1880TheChurchMissionaryIntelligencer',
#  '1881TheChurchMissionaryGleaner',
#  '1881TheChurchMissionaryIntelligencer',
#  '1882TheChurchMissionaryGleaner',
#  '1882TheChurchMissionaryIntelligencer',
#  '1883TheChurchMissionaryGleaner',
#  '1883TheChurchMissionaryIntelligencer',
#  '1883TheEssentialsOfMalayalamGrammar',
#  '1884TheChurchMissionaryGleaner',
#  '1884TheChurchMissionaryIntelligencer',
#  '1885TheChurchMissionaryGleaner',
#  '1885TheChurchMissionaryIntelligencer',
#  '1886TheChurchMissionaryGleaner',
#  '1887TheChurchMissionaryGleaner',
#  '1888TheChurchMissionaryGleaner',
#  '1888TheChurchMissionaryIntelligencer',
#  '1889IndulekhaEdition1',
#  '1889TheChurchMissionaryGleaner',
#  '1889TheChurchMissionaryIntelligencer',
#  '1890TheChurchMissionaryGleaner',
#  '1890TheChurchMissionaryIntelligencer',
#  '1891MalayalamChristianTuneBook',
#  '1891TheChurchMissionaryGleaner',
#  '1891TheChurchMissionaryIntelligencer',
#  '1891YuyomayathmaGeethangal',
#  '1892PirkeAvotShirHaShirimEkhahUFiyutimImTargumMaleyalami',
#  '1892TheChurchMissionaryGleaner',
#  '1892TheChurchMissionaryIntelligencer',
#  '1892_Malankara_Edavaka_Pathrika_Volume_1_Issue_1',
#  '1892_Malankara_Edavaka_Pathrika_Volume_1_Issue_10',
#  '1892_Malankara_Edavaka_Pathrika_Volume_1_Issue_11',
#  '1892_Malankara_Edavaka_Pathrika_Volume_1_Issue_12',
#  '1892_Malankara_Edavaka_Pathrika_Volume_1_Issue_2',
#  '1892_Malankara_Edavaka_Pathrika_Volume_1_Issue_3',
#  '1892_Malankara_Edavaka_Pathrika_Volume_1_Issue_4',
#  '1892_Malankara_Edavaka_Pathrika_Volume_1_Issue_5',
#  '1892_Malankara_Edavaka_Pathrika_Volume_1_Issue_6',
#  '1892_Malankara_Edavaka_Pathrika_Volume_1_Issue_7',
#  '1892_Malankara_Edavaka_Pathrika_Volume_1_Issue_8',
#  '1892_Malankara_Edavaka_Pathrika_Volume_1_Issue_9',
#  '1893MalankaraEdavakaPathrikaVolume02Issue01',
#  '1893TheChurchMissionaryIntelligencer',
#  '1893_Malankara_Edavaka_Pathrika_Volume_02_Issue_01',
#  '1893_Malankara_Edavaka_Pathrika_Volume_02_Issue_02',
#  '1893_Malankara_Edavaka_Pathrika_Volume_02_Issue_03',
#  '1893_Malankara_Edavaka_Pathrika_Volume_02_Issue_04',
#  '1893_Malankara_Edavaka_Pathrika_Volume_02_Issue_05',
#  '1893_Malankara_Edavaka_Pathrika_Volume_02_Issue_06',
#  '1893_Malankara_Edavaka_Pathrika_Volume_02_Issue_07',
#  '1893_Malankara_Edavaka_Pathrika_Volume_02_Issue_08',
#  '1893_Malankara_Edavaka_Pathrika_Volume_02_Issue_09',
#  '1893_Malankara_Edavaka_Pathrika_Volume_02_Issue_10',
#  '1893_Malankara_Edavaka_Pathrika_Volume_02_Issue_11',
#  '1893_Malankara_Edavaka_Pathrika_Volume_02_Issue_12',
#  '1894TheChurchMissionaryIntelligencer',
#  '1894_Malankara_Edavaka_Pathrika_Volume_03_Issue_01',
#  '1894_Malankara_Edavaka_Pathrika_Volume_03_Issue_04',
#  '1894_Malankara_Edavaka_Pathrika_Volume_03_Issue_11',
#  '1894_Malankara_Edavaka_Pathrika_Volume_03_Issue_12',
#  '1895TheChurchMissionaryAtlas',
#  '1895TheChurchMissionaryIntelligencer',
#  '1895_Malankara_Edavaka_Pathrika_Volume_04_Issue_01',
#  '1895_Malankara_Edavaka_Pathrika_Volume_04_Issue_02',
#  '1895_Malankara_Edavaka_Pathrika_Volume_04_Issue_03',
#  '1895_Malankara_Edavaka_Pathrika_Volume_04_Issue_04',
#  '1895_Malankara_Edavaka_Pathrika_Volume_04_Issue_05',
#  '1895_Malankara_Edavaka_Pathrika_Volume_04_Issue_06',
#  '1895_Malankara_Edavaka_Pathrika_Volume_04_Issue_07',
#  '1895_Malankara_Edavaka_Pathrika_Volume_04_Issue_07_201803',
#  '1895_Malankara_Edavaka_Pathrika_Volume_04_Issue_08',
#  '1895_Malankara_Edavaka_Pathrika_Volume_04_Issue_09',
#  '1895_Malankara_Edavaka_Pathrika_Volume_04_Issue_10',
#  '1895_Malankara_Edavaka_Pathrika_Volume_04_Issue_11',
#  '1895_Malankara_Edavaka_Pathrika_Volume_04_Issue_12',
#  '1896YuyomayaBhashaPusthakam',
#  '1896_Malankara_Edavaka_Pathrika_Volume_05_Issue_01',
#  '1896_Malankara_Edavaka_Pathrika_Volume_05_Issue_02',
#  '1896_Malankara_Edavaka_Pathrika_Volume_05_Issue_03',
#  '1896_Malankara_Edavaka_Pathrika_Volume_05_Issue_04',
#  '1896_Malankara_Edavaka_Pathrika_Volume_05_Issue_05',
#  '1896_Malankara_Edavaka_Pathrika_Volume_05_Issue_06',
#  '1896_Malankara_Edavaka_Pathrika_Volume_05_Issue_07',
#  '1896_Malankara_Edavaka_Pathrika_Volume_05_Issue_08',
#  '1896_Malankara_Edavaka_Pathrika_Volume_05_Issue_09',
#  '1896_Malankara_Edavaka_Pathrika_Volume_05_Issue_10',
#  '1896_Malankara_Edavaka_Pathrika_Volume_05_Issue_11',
#  '1896_Malankara_Edavaka_Pathrika_Volume_05_Issue_12',
#  '1897TheChurchMissionaryIntelligencer',
#  '1897_Malankara_Edavaka_Pathrika_Volume_06_Issue_02',
#  '1897_Malankara_Edavaka_Pathrika_Volume_06_Issue_05',
#  '1897_Malankara_Edavaka_Pathrika_Volume_06_Issue_07',
#  '1897_Malankara_Edavaka_Pathrika_Volume_06_Issue_08',
#  '1897_Malankara_Edavaka_Pathrika_Volume_06_Issue_09',
#  '1897_Malankara_Edavaka_Pathrika_Volume_06_Issue_12',
#  '1898MalayalamHymnBook',
#  '1898TheChurchMissionaryGleaner',
#  '1898TheChurchMissionaryIntelligencer',
#  '1898_Malankara_Edavaka_Pathrika_Volume_07_Issue_04',
#  '1899TheChurchMissionaryIntelligencer',
#  '1899_Malankara_Edavaka_Pathrika_Volume_08_Issue_02',
#  '1899_Malankara_Edavaka_Pathrika_Volume_08_Issue_05',
#  '1900TheChurchMissionaryGleaner',
#  '1900TheChurchMissionaryIntelligencer',
#  '1900_Malankara_Edavaka_Pathrika_Volume_09_Issue_09',
#  '1900_Malankara_Edavaka_Pathrika_Volume_09_Issue_12',
#  '1901_Malankara_Edavaka_Pathrika_Volume_10_Issue_01',
#  '1901_Malankara_Edavaka_Pathrika_Volume_10_Issue_02',
#  '1901_Malankara_Edavaka_Pathrika_Volume_10_Issue_03',
#  '1901_Malankara_Edavaka_Pathrika_Volume_10_Issue_04',
#  '1901_Malankara_Edavaka_Pathrika_Volume_10_Issue_05',
#  '1901_Malankara_Edavaka_Pathrika_Volume_10_Issue_06',
#  '1901_Malankara_Edavaka_Pathrika_Volume_10_Issue_07',
#  '1901_Malankara_Edavaka_Pathrika_Volume_10_Issue_08',
#  '1901_Malankara_Edavaka_Pathrika_Volume_10_Issue_09',
#  '1901_Malankara_Edavaka_Pathrika_Volume_10_Issue_10',
#  '1901_Malankara_Edavaka_Pathrika_Volume_10_Issue_11',
#  '1901_Malankara_Edavaka_Pathrika_Volume_10_Issue_12',
#  '1902TheChurchMissionaryGleaner',
#  '1902TheChurchMissionaryIntelligencer',
#  '1902_Malankara_Edavaka_Pathrika_Volume_11_Issue05',
#  '1902_Malankara_Edavaka_Pathrika_Volume_11_Issue_02',
#  '1902_Malankara_Edavaka_Pathrika_Volume_11_Issue_03',
#  '1902_Malankara_Edavaka_Pathrika_Volume_11_Issue_04',
#  '1902_Malankara_Edavaka_Pathrika_Volume_11_Issue_06',
#  '1902_Malankara_Edavaka_Pathrika_Volume_11_Issue_08',
#  '1902_Malankara_Edavaka_Pathrika_Volume_11_Issue_09',
#  '1902_Malankara_Edavaka_Pathrika_Volume_11_Issue_10',
#  '1903TheChurchMissionaryGleaner',
#  '1903TheChurchMissionaryIntelligencer',
#  '1903_Malankara_Edavaka_Pathrika_Volume_12_Issue_04',
#  '1903_Malankara_Edavaka_Pathrika_Volume_12_Issue_05',
#  '1903_Malankara_Edavaka_Pathrika_Volume_12_Issue_06',
#  '1903_Malankara_Edavaka_Pathrika_Volume_12_Issue_07',
#  '1903_Malankara_Edavaka_Pathrika_Volume_12_Issue_08',
#  '1903_Malankara_Edavaka_Pathrika_Volume_12_Issue_09',
#  '1903_Malankara_Edavaka_Pathrika_Volume_12_Issue_10',
#  '1903_Malankara_Edavaka_Pathrika_Volume_12_Issue_11',
#  '1903_Malankara_Edavaka_Pathrika_Volume_12_Issue_12',
#  '1904TheChurchMissionaryIntelligencer',
#  '1904_Malankara_Edavaka_Pathrika_Volume_13_Issue_01',
#  '1904_Malankara_Edavaka_Pathrika_Volume_13_Issue_02',
#  '1904_Malankara_Edavaka_Pathrika_Volume_13_Issue_03',
#  '1904_Malankara_Edavaka_Pathrika_Volume_13_Issue_04',
#  '1904_Malankara_Edavaka_Pathrika_Volume_13_Issue_05',
#  '1904_Malankara_Edavaka_Pathrika_Volume_13_Issue_06',
#  '1904_Malankara_Edavaka_Pathrika_Volume_13_Issue_07',
#  '1904_Malankara_Edavaka_Pathrika_Volume_13_Issue_08',
#  '1904_Malankara_Edavaka_Pathrika_Volume_13_Issue_09',
#  '1904_Malankara_Edavaka_Pathrika_Volume_13_Issue_10',
#  '1904_Malankara_Edavaka_Pathrika_Volume_13_Issue_11',
#  '1904_Malankara_Edavaka_Pathrika_Volume_13_Issue_12',
#  '1905_Malankara_Edavaka_Pathrika_Volume_14_Issue_01',
#  '1905_Malankara_Edavaka_Pathrika_Volume_14_Issue_02',
#  '1905_Malankara_Edavaka_Pathrika_Volume_14_Issue_03',
#  '1905_Malankara_Edavaka_Pathrika_Volume_14_Issue_05',
#  '1905_Malankara_Edavaka_Pathrika_Volume_14_Issue_07',
#  '1905_Malankara_Edavaka_Pathrika_Volume_14_Issue_08',
#  '1905_Malankara_Edavaka_Pathrika_Volume_14_Issue_10',
#  '1905_Malankara_Edavaka_Pathrika_Volume_14_Issue_11',
#  '1905_Malankara_Edavaka_Pathrika_Volume_14_Issue_12',
#  '1906_Malankara_Edavaka_Pathrika_Volume_15_Issue_01',
#  '1906_Malankara_Edavaka_Pathrika_Volume_15_Issue_02',
#  '1906_Malankara_Edavaka_Pathrika_Volume_15_Issue_04',
#  '1906_Malankara_Edavaka_Pathrika_Volume_15_Issue_05',
#  '1906_Malankara_Edavaka_Pathrika_Volume_15_Issue_06',
#  '1906_Malankara_Edavaka_Pathrika_Volume_15_Issue_07',
#  '1906_Malankara_Edavaka_Pathrika_Volume_15_Issue_08',
#  '1906_Malankara_Edavaka_Pathrika_Volume_15_Issue_09',
#  '1906_Malankara_Edavaka_Pathrika_Volume_15_Issue_10',
#  '1906_Malankara_Edavaka_Pathrika_Volume_15_Issue_11',
#  '1906_Malankara_Edavaka_Pathrika_Volume_15_Issue_12',
#  '1907-yakobaya-pathriyarkees-KND',
#  '1907_Hudaya_Canon_Malayalam',
#  '1907_Malankara_Edavaka_Pathrika_Volume_16_Issue_01',
#  '1907_Malankara_Edavaka_Pathrika_Volume_16_Issue_02',
#  '1907_Malankara_Edavaka_Pathrika_Volume_16_Issue_04',
#  '1907_Malankara_Edavaka_Pathrika_Volume_16_Issue_06',
#  '1907_Malankara_Edavaka_Pathrika_Volume_16_Issue_07',
#  '1907_Malankara_Edavaka_Pathrika_Volume_16_Issue_08',
#  '1907_Malankara_Edavaka_Pathrika_Volume_16_Issue_09',
#  '1907_Malankara_Edavaka_Pathrika_Volume_16_Issue_10',
#  '1907_Malankara_Edavaka_Pathrika_Volume_16_Issue_11',
#  '1907_Malankara_Edavaka_Pathrika_Volume_16_Issue_12',
#  '1907_Tripura_Sthothram_Vimsathi',
#  '1908SreeSubhashitharathnakaram',
#  '1908_Keraleeya_Bhasha_Kamsavadha_Champu',
#  '1908_Malankara_Edavaka_Panchangam',
#  '1908_Malankara_Edavaka_Pathrika_Volume_17_Issue_01',
#  '1908_Malankara_Edavaka_Pathrika_Volume_17_Issue_02',
#  '1908_Malankara_Edavaka_Pathrika_Volume_17_Issue_03',
#  '1908_Malankara_Edavaka_Pathrika_Volume_17_Issue_04',
#  '1908_Malankara_Edavaka_Pathrika_Volume_17_Issue_05',
#  '1908_Malankara_Edavaka_Pathrika_Volume_17_Issue_06',
#  '1908_Malankara_Edavaka_Pathrika_Volume_17_Issue_07',
#  '1908_Malankara_Edavaka_Pathrika_Volume_17_Issue_08',
#  '1908_Malankara_Edavaka_Pathrika_Volume_17_Issue_09',
#  '1908_Malankara_Edavaka_Pathrika_Volume_17_Issue_10',
#  '1908_Malankara_Edavaka_Pathrika_Volume_17_Issue_12',
#  '1908_Mathopadesa_Sarangal',
#  '1909-Malankara-Sabha-Tharaka-Volume-006-Issue-01',
#  '1909-Malankara-Sabha-Tharaka-Volume-006-Issue-02',
#  '1909-Malankara-Sabha-Tharaka-Volume-006-Issue-03',
#  '1909-Malankara-Sabha-Tharaka-Volume-006-Issue-04',
#  '1909-Malankara-Sabha-Tharaka-Volume-006-Issue-05',
#  '1909Balavyakaranam',
#  '1909_Malankara_Edavaka_Pathrika_Volume_18_Issue_01',
#  '1909_Malankara_Edavaka_Pathrika_Volume_18_Issue_02',
#  '1909_Malankara_Edavaka_Pathrika_Volume_18_Issue_03',
#  '1909_Malankara_Edavaka_Pathrika_Volume_18_Issue_04',
#  '1909_Malankara_Edavaka_Pathrika_Volume_18_Issue_05',
#  '1909_Malankara_Edavaka_Pathrika_Volume_18_Issue_06',
#  '1909_Malankara_Edavaka_Pathrika_Volume_18_Issue_07',
#  '1909_Malankara_Edavaka_Pathrika_Volume_18_Issue_08',
#  '1909_Malankara_Edavaka_Pathrika_Volume_18_Issue_09',
#  '1909_Malankara_Edavaka_Pathrika_Volume_18_Issue_10',
#  '1909_Malankara_Edavaka_Pathrika_Volume_18_Issue_11',
#  '1909_Malankara_Edavaka_Pathrika_Volume_18_Issue_12',
#  '1910-Malankara-Sabha-Tharaka-Volume-006-Issue-06',
#  '1910-Malankara-Sabha-Tharaka-Volume-006-Issue-07',
#  '1910-Malankara-Sabha-Tharaka-Volume-006-Issue-08',
#  '1910-Malankara-Sabha-Tharaka-Volume-006-Issue-09',
#  '1910-Malankara-Sabha-Tharaka-Volume-006-Issue-10',
#  '1910-Malankara-Sabha-Tharaka-Volume-006-Issue-11',
#  '1910-Malankara-Sabha-Tharaka-Volume-006-Issue-12',
#  '1910SreeVyaghralayeSasthavam',
#  '1910_Malankara_Edavaka_Pathrika_Volume_19_Issue_01',
#  '1911GorakshakaUpadesam',
#  '1911_Malankara_Edavaka_Pathrika_Volume_20_Issue_01',
#  '1911_Malankara_Edavaka_Pathrika_Volume_20_Issue_02',
#  '1911_Malankara_Edavaka_Pathrika_Volume_20_Issue_03',
#  '1912_NallaKuttikal',
#  '1915_Sree_Mahabhagavatham',
#  '1916_Nammude_Chakravarthi',
#  '1917_Leela_Thilakam',
#  '1918KeralaKavikal',
#  '1918ShreeVazhumcodeVol.1No.2',
#  '1918ShreeVazhumcodeVol.1No.3',
#  '1918ShreeVazhumcodeVol.1No.4',
#  '1918_Shree_Vazhumcode_Book1_Vol1',
#  '1919_Pracheena_CheraCharitham',
#  '1919knanayasamudayam',
#  '1920_Athmaposhini_Vol.10_No.9',
#  '1920_Brahmarahasyam',
#  '1920_Christian_Sages',
#  '1920_Christian_Sanyasimar',
#  '1920_Suriyani_Sabha',
#  '1921_Otta_Slokam',
#  '1921_Proverbs_Of_Solomon_KaNiMuSa_Mani_Kathanar',
#  '1928dec-arogyam-masika',
#  '1934_MOS_constitution',
#  '1935-malankaranidhi',
#  '1938_Khalgi_Mahadeva_Sandesam',
#  '1939-pshitha-malayalam-manikathanar',
#  '1940arpbalapadam1ststd',
#  '1950-TCW-Vol4-Issue14',
#  '1950-TCW-Vol4-Issue15',
#  '1950-TCW-Vol4-Issue16',
#  '1950-TCW-Vol4-Issue17',
#  '1950-TCW-Vol4-Issue18',
#  '1950-TCW-Vol4-Issue19',
#  '1950-TCW-Vol4-Issue20',
#  '1950-TCW-Vol4-Issue22',
#  '1950-TCW-Vol4-Issue23',
#  '1951-TCW-Vol5-Issue17',
#  '1951-TCW-Vol5-Issue18',
#  '1951-TCW-Vol5-Issue19',
#  '1951-TCW-Vol5-Issue20',
#  '1951-TCW-Vol5-Issue21',
#  '1951-TCW-Vol5-Issue22',
#  '1951-TCW-Vol5-Issue23',
#  '1951-TCW-Vol5-Issue24',
#  '1951-TCW-Vol5-Issue26',
#  '1951-TCW-Vol5-Issue27',
#  '1951-TCW-Vol5-Issue28',
#  '1951-TCW-Vol5-Issue29',
#  '1951-TCW-Vol5-Issue30',
#  '1951-TCW-Vol5-Issue32',
#  '1953-TCW-Vol7-Issue14',
#  '1953-TCW-Vol7-Issue16',
#  '1953-TCW-Vol7-Issue17',
#  '1953-TCW-Vol7-Issue18',
#  '1953-TCW-Vol7-Issue19',
#  '1953-TCW-Vol7-Issue20',
#  '1953-TCW-Vol7-Issue21',
#  '1953-TCW-Vol7-Issue22',
#  '1953-TCW-Vol7-Issue23',
#  '1953-TCW-Vol7-Issue24',
#  '1953-TCW-Vol7-Issue25',
#  '1953-TCW-Vol7-Issue26',
#  '1953-TCW-Vol7-Issue27',
#  '1953-TCW-Vol7-Issue28',
#  '1953-TCW-Vol7-Issue29',
#  '1953-TCW-Vol7-Issue30',
#  '1954-Varnavidhikal',
#  '1955-TCW-Vol9-Issue10',
#  '1955-TCW-Vol9-Issue11',
#  '1955-TCW-Vol9-Issue13',
#  '1955-TCW-Vol9-Issue14',
#  '1955-TCW-Vol9-Issue15',
#  '1955-TCW-Vol9-Issue16',
#  '1955-TCW-Vol9-Issue17',
#  '1955-TCW-Vol9-Issue18',
#  '1955-TCW-Vol9-Issue2',
#  '1955-TCW-Vol9-Issue20',
#  '1955-TCW-Vol9-Issue21',
#  '1955-TCW-Vol9-Issue22',
#  '1955-TCW-Vol9-Issue23',
#  '1955-TCW-Vol9-Issue24',
#  '1955-TCW-Vol9-Issue25',
#  '1955-TCW-Vol9-Issue26',
#  '1955-TCW-Vol9-Issue27',
#  '1955-TCW-Vol9-Issue3',
#  '1955-TCW-Vol9-Issue4',
#  '1955-TCW-Vol9-Issue5',
#  '1955-TCW-Vol9-Issue7',
#  '1959-TCW-Vol13-Issue22',
#  '1960-TCW-Vol14-Issue23',
#  '1961-TCW-Vol15-Issue21',
#  '1961-TCW-Vol15-Issue42',
#  '1961-TCW-Vol15-Issue48',
#  '1963-TCW-Vol17-Issue10',
#  '1963-TCW-Vol17-Issue47',
#  '1964-TCW-Vol18-Issue18',
#  '1964-TCW-Vol18-Issue8',
#  '1965-TCW-Vol19-Issue3',
#  '1965-TCW-Vol19-Issue46',
#  '1969-TCW-Vol23-Issue10',
#  '1971-TCW-Vol25-Issue10a',
#  '1972julymalankarasevakan',
#  '1995urjavivadamkssp',
#  '2018mundakayamlithopress',
#  '@shiju_alex',
#  'AProgressiveGrammarOfTheMalayalamLanguageForEuropeansFrohnmeyer1913',
#  'BenjaminBailey1843MalayalamNewTestament_201308',
#  'Dharmaraja_raman_pilla_1913',
#  'Ghathakavadam_1877',
#  'Hortus_Indicus_Malabaricus_Volume1',
#  'Hortus_Indicus_Malabaricus_Volume10',
#  'Hortus_Indicus_Malabaricus_Volume11',
#  'Hortus_Indicus_Malabaricus_Volume12',
#  'Hortus_Indicus_Malabaricus_Volume2',
#  'Hortus_Indicus_Malabaricus_Volume3',
#  'Hortus_Indicus_Malabaricus_Volume4',
#  'Hortus_Indicus_Malabaricus_Volume5',
#  'Hortus_Indicus_Malabaricus_Volume6',
#  'Hortus_Indicus_Malabaricus_Volume7',
#  'Hortus_Indicus_Malabaricus_Volume8',
#  'Hortus_Indicus_Malabaricus_Volume9',
#  'JanakeeParinayam1888',
#  'Jewish_Womens_Malayalam_Song_Notebook',
#  'Jnanakeerthangal-1854',
#  'Jnanakeerthangal_1879',
#  'KeralaCharithramAttoorKrishnaPisharadi1933',
#  'MalankaraEdavakaPathrika',
#  'MalankaraSabhayudeDivanyose1901',
#  'MalayalaBhashaCharithram1881',
#  'MalayalaBhashayumSahithyavum1927',
#  'MalayalamFifthReader1918Images',
#  'Malayanmayude_vyakaranam_1863',
#  'PothuvilullaPrarthanagal1898',
#  'PuthiyaNiyamathileLekhanangal1852',
#  'SadacharaPadhathi-1906',
#  'SahithyaPrakashika1916',
#  'Samkshepavedartham_1772',
#  'Sathyavedapusthakam_1910',
#  'TheEvolutionOfMalayalamMorphology1936',
#  'TohfutUlMujahideen',
#  'Travancore_Royal_Court_Judgement_1889',
#  'Vocabulario_Malavarico_1730',
#  'Yukthibhasha1948',
#  'aanopennokk1993konn',
#  'aazhiyudemanorama1958konn',
#  'abhayam0000konn',
#  'adhikaramjanangalkkufirstedn1989kssp',
#  'adhikaramjanangalkkusecondedn1989kssp',
#  'adventurehuckleberryfinn1974std9kerala',
#  'adyakrishikeralaptra0000konn',
#  'adyapakarudesaban0000konn',
#  'agniparvathakk1992konn',
#  'akarinizhalmalrajyam0000konn',
#  'akeshyayumyukaliyumkk1992konn',
#  'akhilalokaanukeral0000konn',
#  'aksharajathaganangal1989kssp',
#  'aksharakalajatha1989kssp',
#  'aksharam1989kssp',
#  'aksharam1989mhrdgoi',
#  'alamarayileswapnangal0000kssp',
#  'amarasimham1859vahadacharya',
#  'americanmanorama1959konn',
#  'amlavrishtikk1983konn',
#  'ammaparayunnu1992kssp',
#  'amulyakaikumkum0000konn',
#  'andhamalaluleela1981konn',
#  'angaganitham1935mnmanalar',
#  'ankaganitham1917kerala',
#  'anthasravangal1981konn',
#  'anuyugammanorama1983konn',
#  'anuyugathilemathrubhumi1975konn',
#  'anweshanaservice1988konn',
#  'apakadamathrubhumi1970konn',
#  'aprathyakshamalayalanadu0000konn',
#  'arabikadal1978gnarayanaswamy',
#  'arabisahisaurabham0000konn',
#  'aranutandennal0000konn',
#  'aristofaneesmalayala0000konn',
#  'arogyacharya1954cokarunakaran',
#  'arogyadharmam1945std4kerala',
#  'arogyaraksha1949kerala',
#  'arunamagazine1952book03issue06',
#  'aspirinmathrubhumi0000konn',
#  'asthama0000kssp',
#  'avisennamalayalanadu1981konn',
#  'ayesteeyes1989kssp',
#  'ayushkamiyam1916tchandapilla',
#  'badalbudjet1993kssp',
#  'balapadamritham1914kesavanvaidyar',
#  'balasahithyathepati000konn',
#  'balavedidinam1991kssp',
#  'balikalathilekku1985kssp',
#  'balolasavajatha1986kssp',
#  'balolsavam1987kssp',
#  'bharatheeyathathinte1981konn',
#  'bhashabodhini1940kerala',
#  'bhashaposhini1917vol21issue10',
#  'bhashaposhini1928vol33issue03',
#  'bhashaposhini1928vol33issue04',
#  'bhashaposhini1928vol33issue05',
#  'bhashaposhini1929vol33issue09',
#  'bhashaposhini1929vol33issue10',
#  'bhoomisasthram1948form1kerala',
#  'bhoomisasthramformthree0000kerala',
#  'bhoomiyudemanorama1958konn',
#  'biasedtv1991konn',
#  'booktrustintegrandalokam0000konn',
#  'britishlkoymavinjakairali1974konn',
#  'bruno1985kssp',
#  'budhakshemanorama1983konn',
#  'carlmarx1912kramakrishnan',
#  'chakravalamanorama1958konnnaren',
#  'chandragupthan1947dwijendralalroy',
#  'chandrakala-origin-and-practice-2014mrj',
#  'charithrakadhakal1968std5kerala',
#  'chathurangathekuri1981konn',
#  'chedichellkummatti1980konn',
#  'chenkolummaravuriyum1966std10kerala',
#  'chenmadhuramano1997konn',
#  'cheriyavaliya2001konn',
#  'cheruthumvaluthum1984kssp',
#  'chithaldeepika0000konn',
#  'chithalthlaluleela1981konn',
#  'chithrangalktrvarma1979kssp',
#  'cinemamasika1946vol01issue01',
#  'cinemayudebhav0000konn',
#  'cinemayudechithra0000konn',
#  'computermanorama1981konn',
#  'cvraman1982kssp',
#  'deepanalathinu1969konn',
#  'denkelnirdhesam1992kssp',
#  'deshabhimana1993kssp',
#  'dhanagarbha0000konn',
#  'dharmarasmi1956std6kerala',
#  'dhooredhooredhoore1990prmadhavapanicker',
#  'duhswapnam1916pappupilla',
#  'eeakramangalkk1991konn',
#  'eebhumimalayalanadu1981konn',
#  'eekayatuvartha1994konn',
#  'einsteinkumkumam0000konn',
#  'ekmdistliteracy1990kssp',
#  'electronicmadkesari1993konn',
#  'ennayunduvalarunna0000konn',
#  'eurekakalikal1992kssp',
#  'expresshway2004kssp',
#  'ezhuthupusthakam1989kssp',
#  'fav-shiju_alex',
#  'feyarikathakeralabhusha1981konn',
#  'fourthreader1908longmans',
#  'gadyajanayithavu-part-1-1932ckmv',
#  'gadyajanayithavu-part-2-1932ckmv',
#  'gadyajanayithavu-part-3-1932ckmv',
#  'gadyajanayithavu-part-4-1932ckmv',
#  'gadyajanayithavu1932dsankarayar',
#  'gadyajanayithavu1932morkothukumaran',
#  'ganitha-padapadhathi1956kerala',
#  'ganithamekmlit1989kssp',
#  'gathagathamroadapakadam1941travancore',
#  'gattumnayangalum1994kssp',
#  'gaveshanakerala1993konn',
#  'geethangal1980kssp',
#  'generalscience1959kerala',
#  'generalscience1961kerala',
#  'generalscience1964std7kerala',
#  'grahangaludemanorama1958konn',
#  'gramavikasanarekha1984kssp',
#  'grammar_of_the_malayalim_language_1839',
#  'gscqpsecondterm1977std9kerala',
#  'gulliverjonathanswift1962std8gpsekhar',
#  'hallydhumakethu1986kssp',
#  'highschoolchemistry1951form4kerala',
#  'hindikaramangalam1993konn',
#  'hridayasasdeepika0000konn',
#  'inayeakarbalarama0000konn',
#  'indiamonnottu1956std9kerala',
#  'indianexpbkreview1974konn',
#  'indiayerakshikkan1992kssp',
#  'indochina1960indiagov',
#  'irupathonnamnutandu1986kssp',
#  'iruttuneengmanorama0000konnnaren',
#  'isrocharacase1995kssp',
#  'jaladevathajayakeralam1960konnnaren',
#  'janakeeyasasthraprasthanam1992kssp',
#  'janakeeyasuthranavivadam2003kssp',
#  'janakiyasuthranam2002kssp',
#  'janangal1989kssp',
#  'janathakal1959khrushchev',
#  'janthulokam1990konn',
#  'janthulokam2007konn',
#  'janthulokam2014konn',
#  'jayakerabkreview1959konn',
#  'jeevanmattu1959konn',
#  'jeevasasthram1975std9kerala',
#  'jwala0000kssp',
#  'kaadathathilklsabdam1981konn',
#  'kadal-enna-kadangatha1998gnarayanaswamy',
#  'kadalkuthiramanorama1964konn',
#  'kadappadukal1960konn',
#  'kaivittupoyakala0000konn',
#  'kalarppuvasthukkal0000kssp',
#  'kalikkamaravindgupta1990kssp',
#  'kalikoottam1992kssp',
#  'kalivela2002kssp',
#  'kallukalkrama1979kssp',
#  'kanakkukumkumam1996konn',
#  'kandathil_varghese_mapila_harisarma_a_d',
#  'kanikonnamalayalanadu0000konn',
#  'kanneermuthukal1971std5kerala',
#  'kannethathaprmad1983kssp',
#  'kannukalikalkk1992konn',
#  'kanyabhoomi1990kssp',
#  'kapilopakhyanam1925sreechithravali',
#  'kariyudekarpooram0000konn',
#  'kariyunnakalpavriksham1984kssp',
#  'karshikameghala1993kssp',
#  'karuna1949kumaranasan',
#  'kathabhinayamala1942std2pala',
#  'kathabhinayamala1942std3pala',
#  'kathabhinayamala1942std4pala',
#  'katturumblaluleela1981konn',
#  'kavimalika1986kssp',
#  'kayalnammude1991kssp',
#  'kazhukanmuthassi1981konn',
#  'keedangalkumkumam0000konn',
#  'kendrathukalmanorama1960konn',
#  'kerala-archives',
#  'kerala-text-books',
#  'keralam1930vol01issue12',
#  'keralanandini1943book2issue1',
#  'keralanjandlaluleela1980konn',
#  'keralapadavali1956std2kerala',
#  'keralapadavali1956std3kerala',
#  'keralapadavali1957kerala',
#  'keralapadyapadavali1952kerala',
#  'keralapanchayathraj1995kssp',
#  'keralathileelectronic0000konn',
#  'keralathilevidyabhyasam1994kssp',
#  'keralathintesampathu1984edn6kssp',
#  'keralavikasanam0000kssp',
#  'keramulamkadukal0000kssp',
#  'kilikoottam0000kssp',
#  'kochi-travancore-mahaidavaka-report1928csi',
#  'kozhiyudelaluleela1981konn',
#  'krishideepika1961keralaagri',
#  'krishnarjunavijayam1905padmulur',
#  'kshayarogamkk1992konn',
#  'kssp-inaguration1962kssp',
#  'ksspsouvenir1983kssp',
#  'kuduthalkalamangalam1993konn',
#  'kuduthalroadukaljanayugam0000konn',
#  'kunjaruraja1952ckmv',
#  'kunjungalemanorama0000konnnaren',
#  'kushtaraogam0000kssp',
#  'kuttigrahakarpooram1993konn',
#  'kuttigrahamanorama1981konn',
#  'lalithaganithasasthram1956std5kerala',
#  'leadkindlylight1989kssp',
#  'librarian1955rmadhavapai',
#  'lsgeography1939form1kerala',
#  'madayanteranmathru1992konn',
#  'maharanisethu1995konn',
#  'mahothsavam1997kssp',
#  'makanevilabalarama0000konn',
#  'malankara-orthodox-syrian-church',
#  'malankara-sabha-magazine',
#  'malayalamfirstreader1926macmillan',
#  'malayalamfourthreader1918kerala',
#  'malayalamreader1926std2kerala',
#  'malayalapadavali1956std4kerala',
#  'malayalapadavali1958std1kerala',
#  'malayalapadavali1961keralagovt',
#  'malayalapadavali1962std8kerala',
#  'malayalapadavalistdx1970kerala',
#  'malayalapadyapadavali1958kerala',
#  'malayayilethiyamalayali1954ksankaran',
#  'malitreasures1994konn',
#  'mamsamthinnunnasasyangal0000kssp',
#  'manaklesamalayanadu1981konn',
#  'manamthalaluleela1981konn',
#  'mannukondoruvyava0000konn',
#  'manushyakeralabhu0000konnnaren',
#  'manushyankatha1989ekmlit',
#  'manushyaparimalayalanadu1982konn',
#  'mapilapattusamrakshi0000konn',
#  'mappilareview1942vol01issue11',
#  'mappilareview1944vol03issue09',
#  'mappilareview1944vol03issue10',
#  'mappilareview1944vol03issue11',
#  'mappilareview1944vol03issue12',
#  'mappilareview1944vol04issue01',
#  'mappilareview1944vol04issue02',
#  'mappilareview1944vol04issue03',
#  'mappilareview1944vol04issue04',
#  'mappilareview1944vol04issue05',
#  'mappilareview1944vol04issue06',
#  'mappilareview1944vol04issue07',
#  'mappilareview1944vol04issue08',
#  'mappilareview1945book04issue12',
#  'mappilareview1945book05issue01',
#  'mappilareview1945book05issue02',
#  'mappilareview1945book05issue03',
#  'mappilareview1945book05issue04',
#  'mappilareview1945book05issue05',
#  'mappilareview1945book05issue06',
#  'mappilareview1945vol04issue09',
#  'mappilareview1945vol04issue10',
#  'mappilareview1946book05issue07',
#  'maramparanja0000kssp',
#  'marathilmalayalanadu0000konn',
#  'marichavareadakal1984kssp',
#  'marichumarayunna0000konn',
#  'markadamalayanadu1981konn',
#  'marksintepatha0000konn',
#  'marunnuchedikal1965konn',
#  'matathintesahisau0000konn',
#  'maulikakeralamini0000konn',
#  'maulikambhashaposh1996konn',
#  'mekaleprabhumanorama0000konn',
#  'middleschoolpauradharmam1950kejob',
#  'mlphysicsterms1952travancore',
#  'mochanam1982kssp',
#  'mollakkayudekuthira1987kssp',
#  'moshitibhugha0000konn',
#  'munnaampadam1949kerala',
#  'muthassikadhakal1961konn',
#  'nadakangal1981kssp',
#  'nadakasilpasala0000kssp',
#  'nadankalapayrkshethram1979konn',
#  'nadintemughangal1972kerala',
#  'naleyudempp1983kssp',
#  'nallanaale1989ekmlit',
#  'nammalariyan2000kssp',
#  'nammalonnu1986kssp',
#  'nammudeaghoshangal1956nkrishnapillay',
#  'nammudebhajanayugam0000konn',
#  'nammudebharanaghatana1964konn',
#  'namukkuchuttumullalokam1989kssp',
#  'nandikedmalayala0000konnnaren',
#  'narakam1981kssp',
#  'navamalika1987kssp',
#  'navyamanapadam1957enchuvadi',
#  'neengikondkumkumam0000konn',
#  'neeralikumkumam0000konn',
#  'niravumnizhakesari1992konn',
#  'njanappana1956std8kerala',
#  'njansthree1990kssp',
#  'onnaampadam1995kssp',
#  'onnamathemalrajyam1947konn',
#  'onnampadamchithirathirunal1941kerala',
#  'oraksharamkunkumam1997konn',
#  'ormayilemunnukk0000konn',
#  'orudheeraswapnam1994kssp',
#  'orugithanjaligurudevan0000konn',
#  'orukunjujanikkunnu0000kssp',
#  'orumaramoruvaram1987kssp',
#  'orunallamanu0000konnnaren',
#  'oruneendabalarama0000konn',
#  'orupracheenaservice1988konn',
#  'orusoppdesabandh0000konnnaren',
#  'oruthadiellintekk0000konn',
#  'oruthakarkeralabhu0000konnnaren',
#  'othukali1984kssp',
#  'ottanthullalukal1980kssp',
#  'ozonepalikumkumam0000konn',
#  'pachavellamdeepika0000konn',
#  'padanolsavam1998kssp',
#  'padayanipattukal0000kssp',
#  'padyapadavali1959kerala',
#  'pambummanumathrubhumi1965konn',
#  'panayapeduthiyabhavi1992kssp',
#  'panchabumkesari1990konn',
#  'panchathanthsupriya1973konn',
#  'panchavadi1961cvkunjuraman',
#  'papi1981kssp',
#  'parasparathar0000konn',
#  'paravakal1962madathupadysivasankaran',
#  'parinamathintekk0000konn',
#  'parishathenthucheyyunnu0000kssp',
#  'parisheelanarekha1981kssp',
#  'parisheelanarekha1982kssp',
#  'patayoduthota1992konn',
#  'pattukal1980kssp',
#  'pauradharmam1956std5kerala',
#  'paurajeevitham1940kerala',
#  'pavakaludejayaker1959konn',
#  'pavanadakangal1988kssp',
#  'pavangalkkuparppidam1954travancore',
#  'pazhancholmala_gundert_1845',
#  'penakalkadha1990kssp',
#  'petamma1995kssp',
#  'pkdjillavikasana1981kssp',
#  'pliniyumprakalalayam0000konn',
#  'poshakahara1985konn',
#  'pothujanaarogyam1955form4nviswambaran',
#  'prakasamdeepika1981konn',
#  'prakrithikkukk1992konn',
#  'prakrithiyile0000konn',
#  'prakshepanamjapkerala1981konn',
#  'prathirodham0000kssp',
#  'prathishedham0000konnnaren',
#  'punarjanthaniniram0000konnnaren',
#  'punyabhumiyudethengal1992kssp',
#  'pushkarmanorama1973konn',
#  'pusthakapremivartha1994konn',
#  'puthanpattukar1987kssp',
#  'puthiyachakramangalam1980konn',
#  'puthiyapadypadhathi1999kssp',
#  'puthiyapiramathrubhu0000konnnaren',
#  'pyramidilekk1992konn',
#  'radiohis1992konnnarenpart03',
#  'radiohis1992konnnarenpart04',
#  'radiohis1992konnnarenpart05',
#  'radiohis1992konnnarenpart06',
#  'radiohis1992konnnarenpart07',
#  'radiohis1992konnnarenpart08',
#  'radiohis1992konnnarenpart09',
#  'radiohis1992konnnarenpart10',
#  'radiohis1992konnnarenpart11',
#  'radiohis1992konnnarenpart12',
#  'radiohis1992konnnarenpart13',
#  'radiosahithyam0000konn',
#  'radiotelevision1992augt30konnnaren',
#  'radioyuntelesahrud1987konn',
#  'rajasthanilebanemanorama1973konn',
#  'rajasthanilemahomanorama1973konn',
#  'rajasthanilemanorama1973konn',
#  'rakshakavacham1935kalavilasini',
#  'ramakathakesari0000konn',
#  'ramayanam_pana',
#  'randampadamtravancore1942kerala',
#  'randampanchavathsarapadhathi1956malayalam',
#  'rangasamvitheatre1962konn',
#  'rasavasthubalarama1981konn',
#  'ravindranathtagore1952form3kerala',
#  'revgeorgemathan-part1-1928ckmv',
#  'revgeorgemathan-part2a-1928ckmv',
#  'revgeorgemathan-part2b-1928ckmv',
#  'revgeorgemathan-part3a-1928ckmv',
#  'revgeorgemathan-part3b-1928ckmv',
#  'revgeorgemathan-part4-1928ckmv',
#  'revgeorgemathan-part5-1928ckmv',
#  'romekathiyerikerala1991konn',
#  'sahakaranabodhini1962kerala',
#  'sahodari1944book03issue06',
#  'sahodari1944vol03issue05',
#  'sahodari1945book03issue07',
#  'sahodari1945book03issue09',
#  'sahodari1945book03issue11',
#  'sahrudaya1941book05issue12',
#  'saksharathayanjamrandam1991kssp',
#  'samadhanathinumanorama0000konn',
#  'samathalam1981kssp',
#  'samathavinjanotsavam1997kssp',
#  'samoohyamanushyanum1982kssp',
#  'samoohyapadangalstdv1961kerala',
#  'sampathikanayamvidyabhyasam0000kssp',
#  'sampathikaparishkaram1991kssp',
#  'samrajyatham1992kssp',
#  'sangeethakauairportjr1982konn',
#  'sankalparangam1940nraman',
#  'santhigeetham1987kssp',
#  'sasthradeepika1981konn',
#  'sasthragathifeb1968kssp',
#  'sasthragathijan1967kssp',
#  'sasthragathijuly1967kssp',
#  'sasthrageethika1984kssp',
#  'sasthragitha0000kssp',
#  'sasthrajanayugam1981konn',
#  'sasthrakeralammay1974kssp',
#  'sasthramgramangalkku1982kssp',
#  'sasthramgrameenarkku1983kssp',
#  'sasthrammlrajyam0000konn',
#  'sasthraparimathru2001kssp',
#  'sasthrapariulgha1962kssp',
#  'sasthrasahigrandhalokam0000konn',
#  'sasthrasankethika1993kssp',
#  'sasthrathekk1992konn',
#  'sasthrathintegrandhalokam0000konn',
#  'sasthrayugathil1968konn',
#  'seemanthiniswayambaram1891narayanannambissan',
#  'seetha1985kssp',
#  'seethampamanorama1973konn',
#  'sevanamekhala1993kssp',
#  'shrothakaludenana0000konn',
#  'sinbad0000std4kerala',
#  'sindhuavaludekatha1963kpalexbasil',
#  'sirthomasmore1948icchacko',
#  'sisuvidyabhyasam1999kssp',
#  'soapinterast2001kssp',
#  'sovietsameeksha1967book2issue8',
#  'spartacs1981kssp',
#  'sreechithirathirunalpadavali1948std5kerala',
#  'sreenarayanaguru1929kdamodaran',
#  'std4malayalapadavali1961kerala',
#  'std4malayalapadavali1971kerala',
#  'std5malayalapadavali1962kerala',
#  'std6veluthampidalava1956vidyodayam',
#  'stvedn2vol11930padpillai',
#  'stvedn2vol21930padpillai',
#  ...]

# %%
len(shiju_list)
# Out:
# 1094

# %%
for item in shiju_list[:3]:

# %%
"https://archive.org/details/kssp-archives?and[]=subject%3A%22Kerala+Archives%22"
# Out:
# 'https://archive.org/details/kssp-archives?and[]=subject%3A%22Kerala+Archives%22'

# %%
subject_list = '''Sasthragathi\nSasthra Keralam Magazine\nSasthra Keralam Magazine, KSSP Science Magazine\nSasthra Keralam Magazine, Malayalam Science Magazine\nEureka Magazine, Malayalam Children's Magazine\nEureka Magazine, Malayalam Children's Magazine\nSasthra Keralam Magazine, KSSP Science Magazine\nSasthra Keralam Magazine, KSSP Science Magazine\nSasthra Keralam Magazine, KSSP Science Magazine\nSasthra Keralam Magazin; Malayalam Science Magazine\nEureka Magazine, Malayalam Children's Magazine\nEureka Magazine, Malayalam Children's Magazine\nEureka Magazine, Malayalam Children's Magazine\nEureka Magazine, Malayalam Children's Magazine\nEureka Magazine\nEureka Magazine, Malayalam Children's Magazine\nEureka Magazine, Malayalam Children's Magazine\nEureka Magazine\nKSSP leaflets;KSSP Health Books\nKSSP leaflets;KSSP Health Books, Measles\nKSSP leaflets; Kerala Health\nKSSP leaflets; First aid, KSSP Health Books\nKSSP leaflets; KSSP Health Books\nKSSP leaflets;KSSP Books about Power\nKSSP leaflets;KSSP Health Books\nKSSP leaflets;KSSP Health Books\nKSSP leaflets;Kerala Energy Problem;KSSP Energy Books\nKSSP leaflets;KSSP Energy Books;Power Problex in Kerala\nKSSP leaflets;Kerala Energy;KSSP Ecology Books\nKSSP leaflets; KSSP Development Books; Kerala Development\nKSSP leaflets; KSSP Development Books; Kerala Development\nKSSP leaflets;KSSP Health Books;Health Survey\nKSSP leaflets;Kerala Energy Problem;KSSP Energy Books\nKSSP leaflets;Kerala Power Problem\nKSSP leaflets;KSSP Health Books;Kerala Health Problem\nKSSP leaflets;KSSP Health Books;Health Survey\nKSSP leaflets;KSSP Gender Books\nKSSP leaflets about Gender\nKSSP leaflets;KSSP Gender Books\nKSSP leaflets;KSSP Health Books\nKSSP leaflets;KSSP Health Books;Health Survey\nKSSP leaflets; KSSP Books about Gender Bias\nKSSP leaflets;KSSP Gender Books\nKSSP leaflets;KSSP Gender Books\nKSSP leaflets;KSSP Health Books\nKSSP leaflets;Kerala Energy Problem;KSSP Energy Books\nKSSP leaflets;KSSP Gender Books\nKSSP leaflets;KSSP Gender Books;Civil Code and Gender Bias\nKSSP leaflets;KSSP Health Books\nKSSP leaflets;KSSP Health Books\nKSSP leaflets;KSSP Health Books;Medicine Price Hike\nKSSP leaflets;KSSP Gender Books;Gender Bias\nKSSP leaflets; Women's Health; KSSP Books about Health; KSSP books about women\nKSSP leaflets;KSSP Gender Books;Gender Bias in Kerala\nKSSP leaflets;KSSP Health Books;Leptospirosis;Plague\nKSSP leaflets;Power Problem of Kerala, KSSP Books about Power\nKSSP leaflets;KSSP Health Books\nKSSP leaflets;Kerala Public Education;KSSP Education Books\nKSSP leaflets;Kerala Public Education;KSSP Education Books; Vidyabhyasa Jadha-95\nKSSP leaflets;Kerala Public Education;KSSP Education Books;Vidyabhyasa Jadha-95\nKSSP leaflets;Kerala Public Education, Vidyabhyasa Jadha-95\nKSSP leaflets;Kerala Public Education;KSSP Education Books;KSSP and Education Debates\nKSSP leaflets; Kerala Education; KSSP Books about Education; Vidyabhyasa Jadha-95\n['Kerala Electricity', 'KSSP leaflets', 'Kerala Energy']\n['Planning, evelopment', 'Kerala Archives']\n['Decentralization, Planning, Democracy', 'Kerala Archives']\nKala Jatha, Street Theatre\n['Ernakulam District Total Literarcy Programme', 'Kerala Literacy']\nErnakulam District Total Literarcy Programme\n['Ernakulam District Total Literarcy Programme', 'Kerala Literacy']\nKilikkkoottam Jadha, Street Theatre\nStreet Theatre\nHealth Education, Asthma\nKSSP leaflets;KSSP Health Books\nKala Jatha, Street Theatre\n['Economics, Badjet', 'Kerala Swashraya Samithy']\nBalavedi, Science History\nSasthra Kala Jatha, Street Theatre\nBalalsava Jatha, Street Theatre\nBalolsava Songs\nSasthra Kala Jatha, Street Theatre\nkssp-science books, P R Madhavappanikkar, Malayalam Physics Books\nPainting, Art, History\nScience Education, Biography, C V Raman\n['Dunkal Draft', 'Kerala Archives']\n['New Economic Policy of India, Kerala Swasraya Samithi', 'Kerala Sasthra Sahithya Parishad']\n['kssp-science books', 'P R Madhavappanikkar', 'Malayalam Physics Books']\n['Ernakulam District Total Literarcy Programme', 'Kerala Literacy']\nScience Education\nEureka Magazine, Malayalam Children's Magazine\nEureka Magazine\nKerala Development, Express Highway, Jalanidhi\n['Ernakulam District Total Literarcy Programme', 'Kerala Literacy']\n['Ernakulam District Total Literarcy Programme; Mathematics Hand Book', 'Kerala Literacy']\n['Globalization, Gatt Agreement', 'Kerala Swashraya Samithy']\n['Sasthra Kala Jatha', 'Kerala Archives']\nKerala Economy, Rural Development\nAstronomy, Halley's comet\n['Globalization, Dunkal Draft, Indian Economy', 'Kerala Swashraya Samithy']\nSasthra Kala Jatha, Street Theatre\n['ISRO; KSSP leaflets', 'Kerala Archives']\nPeople's Science Movement in Kerala\nPeople's Planning\nPeople's Planning; Participative Democracy, Decentralization\n['Education, Literacy', 'Kerala Literacy']\nBhopal Gas Tragedy\nScience Education, Adulteration\nMalayalam Science Education Books'''.split("\n")

# %%
subject_list = [x.replace('"', '') for x in subject_list]

# %%
sl = []
for subject_text in subject_list:
    sl.append(normalize_subject(subject_text))

# %%
sl = [normalize_subject(x) for x in sl]

# %%
sl
# Out:
# ['Sasthragathi',
#  'Sasthra Keralam Magazine',
#  'Sasthra Keralam Magazine; KSSP Science Magazine',
#  'Sasthra Keralam Magazine; Malayalam Science Magazine',
#  "Eureka Magazine; Malayalam Children's Magazine",
#  "Eureka Magazine; Malayalam Children's Magazine",
#  'Sasthra Keralam Magazine; KSSP Science Magazine',
#  'Sasthra Keralam Magazine; KSSP Science Magazine',
#  'Sasthra Keralam Magazine; KSSP Science Magazine',
#  'Sasthra Keralam Magazin; Malayalam Science Magazine',
#  "Eureka Magazine; Malayalam Children's Magazine",
#  "Eureka Magazine; Malayalam Children's Magazine",
#  "Eureka Magazine; Malayalam Children's Magazine",
#  "Eureka Magazine; Malayalam Children's Magazine",
#  'Eureka Magazine',
#  "Eureka Magazine; Malayalam Children's Magazine",
#  "Eureka Magazine; Malayalam Children's Magazine",
#  'Eureka Magazine',
#  'KSSP leaflets; KSSP Health Books',
#  'KSSP leaflets; KSSP Health Books; Measles',
#  'KSSP leaflets; Kerala Health',
#  'KSSP leaflets; First aid; KSSP Health Books',
#  'KSSP leaflets; KSSP Health Books',
#  'KSSP leaflets; KSSP Books about Power',
#  'KSSP leaflets; KSSP Health Books',
#  'KSSP leaflets; KSSP Health Books',
#  'KSSP leaflets; Kerala Energy Problem; KSSP Energy Books',
#  'KSSP leaflets; KSSP Energy Books; Power Problex in Kerala',
#  'KSSP leaflets; Kerala Energy; KSSP Ecology Books',
#  'KSSP leaflets; KSSP Development Books; Kerala Development',
#  'KSSP leaflets; KSSP Development Books; Kerala Development',
#  'KSSP leaflets; KSSP Health Books; Health Survey',
#  'KSSP leaflets; Kerala Energy Problem; KSSP Energy Books',
#  'KSSP leaflets; Kerala Power Problem',
#  'KSSP leaflets; KSSP Health Books; Kerala Health Problem',
#  'KSSP leaflets; KSSP Health Books; Health Survey',
#  'KSSP leaflets; KSSP Gender Books',
#  'KSSP leaflets about Gender',
#  'KSSP leaflets; KSSP Gender Books',
#  'KSSP leaflets; KSSP Health Books',
#  'KSSP leaflets; KSSP Health Books; Health Survey',
#  'KSSP leaflets; KSSP Books about Gender Bias',
#  'KSSP leaflets; KSSP Gender Books',
#  'KSSP leaflets; KSSP Gender Books',
#  'KSSP leaflets; KSSP Health Books',
#  'KSSP leaflets; Kerala Energy Problem; KSSP Energy Books',
#  'KSSP leaflets; KSSP Gender Books',
#  'KSSP leaflets; KSSP Gender Books; Civil Code and Gender Bias',
#  'KSSP leaflets; KSSP Health Books',
#  'KSSP leaflets; KSSP Health Books',
#  'KSSP leaflets; KSSP Health Books; Medicine Price Hike',
#  'KSSP leaflets; KSSP Gender Books; Gender Bias',
#  "KSSP leaflets; Women's Health; KSSP Books about Health; KSSP books about women",
#  'KSSP leaflets; KSSP Gender Books; Gender Bias in Kerala',
#  'KSSP leaflets; KSSP Health Books; Leptospirosis; Plague',
#  'KSSP leaflets; Power Problem of Kerala; KSSP Books about Power',
#  'KSSP leaflets; KSSP Health Books',
#  'KSSP leaflets; Kerala Public Education; KSSP Education Books',
#  'KSSP leaflets; Kerala Public Education; KSSP Education Books; Vidyabhyasa Jadha-95',
#  'KSSP leaflets; Kerala Public Education; KSSP Education Books; Vidyabhyasa Jadha-95',
#  'KSSP leaflets; Kerala Public Education; Vidyabhyasa Jadha-95',
#  'KSSP leaflets; Kerala Public Education; KSSP Education Books; KSSP and Education Debates',
#  'KSSP leaflets; Kerala Education; KSSP Books about Education; Vidyabhyasa Jadha-95',
#  "['Kerala Electricity'; 'KSSP leaflets'; 'Kerala Energy']",
#  "['Planning; evelopment'; 'Kerala Archives']",
#  "['Decentralization; Planning; Democracy'; 'Kerala Archives']",
#  'Kala Jatha; Street Theatre',
#  "['Ernakulam District Total Literarcy Programme'; 'Kerala Literacy']",
#  'Ernakulam District Total Literarcy Programme',
#  "['Ernakulam District Total Literarcy Programme'; 'Kerala Literacy']",
#  'Kilikkkoottam Jadha; Street Theatre',
#  'Street Theatre',
#  'Health Education; Asthma',
#  'KSSP leaflets; KSSP Health Books',
#  'Kala Jatha; Street Theatre',
#  "['Economics; Badjet'; 'Kerala Swashraya Samithy']",
#  'Balavedi; Science History',
#  'Sasthra Kala Jatha; Street Theatre',
#  'Balalsava Jatha; Street Theatre',
#  'Balolsava Songs',
#  'Sasthra Kala Jatha; Street Theatre',
#  'kssp-science books; P R Madhavappanikkar; Malayalam Physics Books',
#  'Painting; Art; History',
#  'Science Education; Biography; C V Raman',
#  "['Dunkal Draft'; 'Kerala Archives']",
#  "['New Economic Policy of India; Kerala Swasraya Samithi'; 'Kerala Sasthra Sahithya Parishad']",
#  "['kssp-science books'; 'P R Madhavappanikkar'; 'Malayalam Physics Books']",
#  "['Ernakulam District Total Literarcy Programme'; 'Kerala Literacy']",
#  'Science Education',
#  "Eureka Magazine; Malayalam Children's Magazine",
#  'Eureka Magazine',
#  'Kerala Development; Express Highway; Jalanidhi',
#  "['Ernakulam District Total Literarcy Programme'; 'Kerala Literacy']",
#  "['Ernakulam District Total Literarcy Programme; Mathematics Hand Book'; 'Kerala Literacy']",
#  "['Globalization; Gatt Agreement'; 'Kerala Swashraya Samithy']",
#  "['Sasthra Kala Jatha'; 'Kerala Archives']",
#  'Kerala Economy; Rural Development',
#  "Astronomy; Halley's comet",
#  "['Globalization; Dunkal Draft; Indian Economy'; 'Kerala Swashraya Samithy']",
#  'Sasthra Kala Jatha; Street Theatre',
#  "['ISRO; KSSP leaflets'; 'Kerala Archives']",
#  "People's Science Movement in Kerala",
#  "People's Planning",
#  "People's Planning; Participative Democracy; Decentralization",
#  "['Education; Literacy'; 'Kerala Literacy']",
#  'Bhopal Gas Tragedy',
#  'Science Education; Adulteration',
#  'Malayalam Science Education Books']
